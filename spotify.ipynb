# %%
from bs4 import BeautifulSoup
from urllib.request import urlopen

# %%
url = 'https://open.spotify.com/playlist/37i9dQZEVXbMnZEatlMSiu/'
html = urlopen(url)
html_doc = BeautifulSoup(html,"html.parser")
print(html_doc.prettify())
# Out:
# <!DOCTYPE html>
# <html class="no-css3-filters no-focus-outline" dir="ltr" lang="en">
#  <head>
#   <meta charset="utf-8"/>
#   <title>
#    Taiwan Top 50 on Spotify
#   </title>
#   <meta content="Your daily update of the most played tracks in Taiwan right now." name="description">
#    <meta content="Taiwan Top 50, a playlist by spotifycharts" property="og:title"/>
#    <meta content="Your daily update of the most played tracks in Taiwan right now." property="og:description"/>
#    <meta content="https://open.spotify.com/playlist/37i9dQZEVXbMnZEatlMSiu" property="og:url"/>
#    <meta content="https://charts-images.scdn.co/assets/locale_en/regional/daily/region_tw_large.jpg" property="og:image"/>
#    <meta content="music.playlist" property="og:type"/>
#    <meta content="https://open.spotify.com/user/spotifycharts" property="music:creator"/>
#    <meta content="50" property="music:song_count"/>
#    <meta content="https://open.spotify.com/track/3OC84eKMxRJ4x0Hcwl9i4i" property="music:song"/>
#    <meta content="1" property="music:song:track"/>
#    <meta content="https://open.spotify.com/track/4RewTiGEGoO7FWNZUmp1f4" property="music:song"/>
#    <meta content="2" property="music:song:track"/>
#    <meta content="https://open.spotify.com/track/3IveWAHTMxZA4KYBPnylq5" property="music:song"/>
#    <meta content="3" property="music:song:track"/>
#    <meta content="https://open.spotify.com/track/69zgyr5HVKdInjeKpq1qHa" property="music:song"/>
#    <meta content="4" property="music:song:track"/>
#    <meta content="https://open.spotify.com/track/1Ytgo9ipdlTsf6wlg6sXf3" property="music:song"/>
#    <meta content="5" property="music:song:track"/>
#    <meta content="https://open.spotify.com/track/5cU1O9P0EDA0rPkPDykhIm" property="music:song"/>
#    <meta content="6" property="music:song:track"/>
#    <meta content="https://open.spotify.com/track/7lPN2DXiMsVn7XUKtOW1CS" property="music:song"/>
#    <meta content="7" property="music:song:track"/>
#    <meta content="https://open.spotify.com/track/4saklk6nie3yiGePpBwUoc" property="music:song"/>
#    <meta content="8" property="music:song:track"/>
#    <meta content="https://open.spotify.com/track/3oRP6yGs5d0kFpGRRzzaS8" property="music:song"/>
#    <meta content="9" property="music:song:track"/>
#    <meta content="https://open.spotify.com/track/0cSkn2l67csUljEy0EEBPn" property="music:song"/>
#    <meta content="10" property="music:song:track"/>
#    <meta content="https://open.spotify.com/track/5QbK5PrR9wbog3M5vVAn2n" property="music:song"/>
#    <meta content="11" property="music:song:track"/>
#    <meta content="https://open.spotify.com/track/4WnwrZsv8lVHt0ribAeL1I" property="music:song"/>
#    <meta content="12" property="music:song:track"/>
#    <meta content="https://open.spotify.com/track/7xTOqnsOV6qHBPWoCWpzGM" property="music:song"/>
#    <meta content="13" property="music:song:track"/>
#    <meta content="https://open.spotify.com/track/3t8M86tiO0aKMMTXzRrFn8" property="music:song"/>
#    <meta content="14" property="music:song:track"/>
#    <meta content="https://open.spotify.com/track/7kEjyjL7p62JSKE7Eiz1WG" property="music:song"/>
#    <meta content="15" property="music:song:track"/>
#    <meta content="https://open.spotify.com/track/31qCy5ZaophVA81wtlwLc4" property="music:song"/>
#    <meta content="16" property="music:song:track"/>
#    <meta content="https://open.spotify.com/track/0bIbgooxvBkww2ZGeu8VMR" property="music:song"/>
#    <meta content="17" property="music:song:track"/>
#    <meta content="https://open.spotify.com/track/6GD7YFzkLd6nxKrbGqtKpp" property="music:song"/>
#    <meta content="18" property="music:song:track"/>
#    <meta content="https://open.spotify.com/track/4YxVgJAkGsUnqLvEzjz8Ry" property="music:song"/>
#    <meta content="19" property="music:song:track"/>
#    <meta content="https://open.spotify.com/track/0KWnRv3wxjltYVB3MqjNd2" property="music:song"/>
#    <meta content="20" property="music:song:track"/>
#    <meta content="https://open.spotify.com/track/0E4Y1XIbs8GrAT1YqVy6dq" property="music:song"/>
#    <meta content="21" property="music:song:track"/>
#    <meta content="https://open.spotify.com/track/35mvY5S1H3J2QZyna3TFe0" property="music:song"/>
#    <meta content="22" property="music:song:track"/>
#    <meta content="https://open.spotify.com/track/56wVfJKtnwlSZtC4NVgIrf" property="music:song"/>
#    <meta content="23" property="music:song:track"/>
#    <meta content="https://open.spotify.com/track/3Uo7WG0vmLQ07WB4BDwy7D" property="music:song"/>
#    <meta content="24" property="music:song:track"/>
#    <meta content="https://open.spotify.com/track/66YKSygcUZHHqHJZcWslI3" property="music:song"/>
#    <meta content="25" property="music:song:track"/>
#    <meta content="https://open.spotify.com/track/5nujrmhLynf4yMoMtj8AQF" property="music:song"/>
#    <meta content="26" property="music:song:track"/>
#    <meta content="https://open.spotify.com/track/6lZKB76djHxzO0p2Y3E8vj" property="music:song"/>
#    <meta content="27" property="music:song:track"/>
#    <meta content="https://open.spotify.com/track/56XaEf9Mo2Njaxa9TIn5LR" property="music:song"/>
#    <meta content="28" property="music:song:track"/>
#    <meta content="https://open.spotify.com/track/1HbA4N1MiOsPthALesGFR1" property="music:song"/>
#    <meta content="29" property="music:song:track"/>
#    <meta content="https://open.spotify.com/track/2h5j6lshsRkShTQ527SOlj" property="music:song"/>
#    <meta content="30" property="music:song:track"/>
#    <meta content="AD" property="og:restrictions:country:allowed"/>
#    <meta content="AE" property="og:restrictions:country:allowed"/>
#    <meta content="AL" property="og:restrictions:country:allowed"/>
#    <meta content="AR" property="og:restrictions:country:allowed"/>
#    <meta content="AT" property="og:restrictions:country:allowed"/>
#    <meta content="AU" property="og:restrictions:country:allowed"/>
#    <meta content="BA" property="og:restrictions:country:allowed"/>
#    <meta content="BE" property="og:restrictions:country:allowed"/>
#    <meta content="BG" property="og:restrictions:country:allowed"/>
#    <meta content="BH" property="og:restrictions:country:allowed"/>
#    <meta content="BO" property="og:restrictions:country:allowed"/>
#    <meta content="BR" property="og:restrictions:country:allowed"/>
#    <meta content="BY" property="og:restrictions:country:allowed"/>
#    <meta content="CA" property="og:restrictions:country:allowed"/>
#    <meta content="CH" property="og:restrictions:country:allowed"/>
#    <meta content="CL" property="og:restrictions:country:allowed"/>
#    <meta content="CO" property="og:restrictions:country:allowed"/>
#    <meta content="CR" property="og:restrictions:country:allowed"/>
#    <meta content="CY" property="og:restrictions:country:allowed"/>
#    <meta content="CZ" property="og:restrictions:country:allowed"/>
#    <meta content="DE" property="og:restrictions:country:allowed"/>
#    <meta content="DK" property="og:restrictions:country:allowed"/>
#    <meta content="DO" property="og:restrictions:country:allowed"/>
#    <meta content="DZ" property="og:restrictions:country:allowed"/>
#    <meta content="EC" property="og:restrictions:country:allowed"/>
#    <meta content="EE" property="og:restrictions:country:allowed"/>
#    <meta content="EG" property="og:restrictions:country:allowed"/>
#    <meta content="ES" property="og:restrictions:country:allowed"/>
#    <meta content="FI" property="og:restrictions:country:allowed"/>
#    <meta content="FR" property="og:restrictions:country:allowed"/>
#    <meta content="GB" property="og:restrictions:country:allowed"/>
#    <meta content="GR" property="og:restrictions:country:allowed"/>
#    <meta content="GT" property="og:restrictions:country:allowed"/>
#    <meta content="HK" property="og:restrictions:country:allowed"/>
#    <meta content="HN" property="og:restrictions:country:allowed"/>
#    <meta content="HR" property="og:restrictions:country:allowed"/>
#    <meta content="HU" property="og:restrictions:country:allowed"/>
#    <meta content="ID" property="og:restrictions:country:allowed"/>
#    <meta content="IE" property="og:restrictions:country:allowed"/>
#    <meta content="IL" property="og:restrictions:country:allowed"/>
#    <meta content="IN" property="og:restrictions:country:allowed"/>
#    <meta content="IS" property="og:restrictions:country:allowed"/>
#    <meta content="IT" property="og:restrictions:country:allowed"/>
#    <meta content="JO" property="og:restrictions:country:allowed"/>
#    <meta content="JP" property="og:restrictions:country:allowed"/>
#    <meta content="KR" property="og:restrictions:country:allowed"/>
#    <meta content="KW" property="og:restrictions:country:allowed"/>
#    <meta content="KZ" property="og:restrictions:country:allowed"/>
#    <meta content="LB" property="og:restrictions:country:allowed"/>
#    <meta content="LI" property="og:restrictions:country:allowed"/>
#    <meta content="LT" property="og:restrictions:country:allowed"/>
#    <meta content="LU" property="og:restrictions:country:allowed"/>
#    <meta content="LV" property="og:restrictions:country:allowed"/>
#    <meta content="MA" property="og:restrictions:country:allowed"/>
#    <meta content="MC" property="og:restrictions:country:allowed"/>
#    <meta content="MD" property="og:restrictions:country:allowed"/>
#    <meta content="ME" property="og:restrictions:country:allowed"/>
#    <meta content="MK" property="og:restrictions:country:allowed"/>
#    <meta content="MT" property="og:restrictions:country:allowed"/>
#    <meta content="MX" property="og:restrictions:country:allowed"/>
#    <meta content="MY" property="og:restrictions:country:allowed"/>
#    <meta content="NI" property="og:restrictions:country:allowed"/>
#    <meta content="NL" property="og:restrictions:country:allowed"/>
#    <meta content="NO" property="og:restrictions:country:allowed"/>
#    <meta content="NZ" property="og:restrictions:country:allowed"/>
#    <meta content="OM" property="og:restrictions:country:allowed"/>
#    <meta content="PA" property="og:restrictions:country:allowed"/>
#    <meta content="PE" property="og:restrictions:country:allowed"/>
#    <meta content="PH" property="og:restrictions:country:allowed"/>
#    <meta content="PL" property="og:restrictions:country:allowed"/>
#    <meta content="PS" property="og:restrictions:country:allowed"/>
#    <meta content="PT" property="og:restrictions:country:allowed"/>
#    <meta content="PY" property="og:restrictions:country:allowed"/>
#    <meta content="QA" property="og:restrictions:country:allowed"/>
#    <meta content="RO" property="og:restrictions:country:allowed"/>
#    <meta content="RS" property="og:restrictions:country:allowed"/>
#    <meta content="RU" property="og:restrictions:country:allowed"/>
#    <meta content="SA" property="og:restrictions:country:allowed"/>
#    <meta content="SE" property="og:restrictions:country:allowed"/>
#    <meta content="SG" property="og:restrictions:country:allowed"/>
#    <meta content="SI" property="og:restrictions:country:allowed"/>
#    <meta content="SK" property="og:restrictions:country:allowed"/>
#    <meta content="SV" property="og:restrictions:country:allowed"/>
#    <meta content="TH" property="og:restrictions:country:allowed"/>
#    <meta content="TN" property="og:restrictions:country:allowed"/>
#    <meta content="TR" property="og:restrictions:country:allowed"/>
#    <meta content="TW" property="og:restrictions:country:allowed"/>
#    <meta content="UA" property="og:restrictions:country:allowed"/>
#    <meta content="US" property="og:restrictions:country:allowed"/>
#    <meta content="UY" property="og:restrictions:country:allowed"/>
#    <meta content="VN" property="og:restrictions:country:allowed"/>
#    <meta content="XK" property="og:restrictions:country:allowed"/>
#    <meta content="ZA" property="og:restrictions:country:allowed"/>
#    <meta content="https://charts-images.scdn.co/assets/locale_en/regional/daily/region_tw_large.jpg" property="twitter:image"/>
#    <meta content="Spotify" property="twitter:audio:partner"/>
#    <meta content="Taiwan Top 50" property="twitter:title"/>
#    <meta content="324684580" property="twitter:app:id:iphone"/>
#    <meta content="com.spotify.music" property="twitter:app:id:googleplay"/>
#    <meta content="@spotify" property="twitter:site"/>
#    <meta content="Your daily update of the most played tracks in Taiwan right now." property="twitter:description"/>
#    <meta content="380" property="twitter:player:height"/>
#    <meta content="300" property="twitter:player:width"/>
#    <meta content="audio" property="twitter:card"/>
#    <meta content="Crowd Lu, IU, Ren Ran, and others" property="twitter:audio:artist_name"/>
#    <meta content="https://open.spotify.com/embed/playlist/37i9dQZEVXbMnZEatlMSiu?utm_campaign=twitter-player&amp;utm_source=open&amp;utm_medium=twitter" property="twitter:player"/>
#    <meta content="Spotify" property="al:android:app_name"/>
#    <meta content="com.spotify.music" property="al:android:package"/>
#    <meta content="spotify://playlist/37i9dQZEVXbMnZEatlMSiu" property="al:android:url"/>
#    <meta content="Spotify" property="al:ios:app_name"/>
#    <meta content="324684580" property="al:ios:app_store_id"/>
#    <meta content="spotify://playlist/37i9dQZEVXbMnZEatlMSiu" property="al:ios:url"/>
#    <meta content="Spotify" property="og:site_name"/>
#    <meta content="notranslate" property="google"/>
#    <meta content="174829003346" property="fb:app_id"/>
#    <meta content="noindex" name="robots"/>
#    <link href="https://open.spotify.com/playlist/37i9dQZEVXbMnZEatlMSiu" rel="canonical"/>
#    <link href="https://open.spotify.com/playlist/37i9dQZEVXbMnZEatlMSiu/metadata" rel="opengraph"/>
#    <link href="android-app://com.spotify.music/spotify/playlist/37i9dQZEVXbMnZEatlMSiu" rel="alternate"/>
#    <script type="application/ld+json">
#     {"@context":"http:\/\/schema.googleapis.com\/","@type":"MusicGroup","@id":"https:\/\/open.spotify.com\/playlist\/37i9dQZEVXbMnZEatlMSiu","url":"https:\/\/open.spotify.com\/playlist\/37i9dQZEVXbMnZEatlMSiu","name":"Taiwan Top 50","description":"Your daily update of the most played tracks in Taiwan right now.","potentialAction":{"@type":"ListenAction","target":[{"@type":"EntryPoint","urlTemplate":"https:\/\/open.spotify.com\/playlist\/37i9dQZEVXbMnZEatlMSiu?autoplay=true","actionPlatform":["http:\/\/schema.org\/DesktopWebPlatform","http:\/\/schema.org\/IOSPlatform","http:\/\/schema.googleapis.com\/GoogleAudioCast","http:\/\/schema.googleapis.com\/GoogleVideoCast"]},"android-app:\/\/com.spotify.music\/spotify\/playlist\/37i9dQZEVXbMnZEatlMSiu\/play"],"expectsAcceptanceOf":{"@type":"Offer","category":"free","eligibleRegion":[{"@type":"Country","name":"AD"},{"@type":"Country","name":"AE"},{"@type":"Country","name":"AL"},{"@type":"Country","name":"AR"},{"@type":"Country","name":"AT"},{"@type":"Country","name":"AU"},{"@type":"Country","name":"BA"},{"@type":"Country","name":"BE"},{"@type":"Country","name":"BG"},{"@type":"Country","name":"BH"},{"@type":"Country","name":"BO"},{"@type":"Country","name":"BR"},{"@type":"Country","name":"BY"},{"@type":"Country","name":"CA"},{"@type":"Country","name":"CH"},{"@type":"Country","name":"CL"},{"@type":"Country","name":"CO"},{"@type":"Country","name":"CR"},{"@type":"Country","name":"CY"},{"@type":"Country","name":"CZ"},{"@type":"Country","name":"DE"},{"@type":"Country","name":"DK"},{"@type":"Country","name":"DO"},{"@type":"Country","name":"DZ"},{"@type":"Country","name":"EC"},{"@type":"Country","name":"EE"},{"@type":"Country","name":"EG"},{"@type":"Country","name":"ES"},{"@type":"Country","name":"FI"},{"@type":"Country","name":"FR"},{"@type":"Country","name":"GB"},{"@type":"Country","name":"GR"},{"@type":"Country","name":"GT"},{"@type":"Country","name":"HK"},{"@type":"Country","name":"HN"},{"@type":"Country","name":"HR"},{"@type":"Country","name":"HU"},{"@type":"Country","name":"ID"},{"@type":"Country","name":"IE"},{"@type":"Country","name":"IL"},{"@type":"Country","name":"IN"},{"@type":"Country","name":"IS"},{"@type":"Country","name":"IT"},{"@type":"Country","name":"JO"},{"@type":"Country","name":"JP"},{"@type":"Country","name":"KR"},{"@type":"Country","name":"KW"},{"@type":"Country","name":"KZ"},{"@type":"Country","name":"LB"},{"@type":"Country","name":"LI"},{"@type":"Country","name":"LT"},{"@type":"Country","name":"LU"},{"@type":"Country","name":"LV"},{"@type":"Country","name":"MA"},{"@type":"Country","name":"MC"},{"@type":"Country","name":"MD"},{"@type":"Country","name":"ME"},{"@type":"Country","name":"MK"},{"@type":"Country","name":"MT"},{"@type":"Country","name":"MX"},{"@type":"Country","name":"MY"},{"@type":"Country","name":"NI"},{"@type":"Country","name":"NL"},{"@type":"Country","name":"NO"},{"@type":"Country","name":"NZ"},{"@type":"Country","name":"OM"},{"@type":"Country","name":"PA"},{"@type":"Country","name":"PE"},{"@type":"Country","name":"PH"},{"@type":"Country","name":"PL"},{"@type":"Country","name":"PS"},{"@type":"Country","name":"PT"},{"@type":"Country","name":"PY"},{"@type":"Country","name":"QA"},{"@type":"Country","name":"RO"},{"@type":"Country","name":"RS"},{"@type":"Country","name":"RU"},{"@type":"Country","name":"SA"},{"@type":"Country","name":"SE"},{"@type":"Country","name":"SG"},{"@type":"Country","name":"SI"},{"@type":"Country","name":"SK"},{"@type":"Country","name":"SV"},{"@type":"Country","name":"TH"},{"@type":"Country","name":"TN"},{"@type":"Country","name":"TR"},{"@type":"Country","name":"TW"},{"@type":"Country","name":"UA"},{"@type":"Country","name":"US"},{"@type":"Country","name":"UY"},{"@type":"Country","name":"VN"},{"@type":"Country","name":"XK"},{"@type":"Country","name":"ZA"}]}}}
#    </script>
#    <meta content="width=device-width,initial-scale=1,maximum-scale=1,viewport-fit=cover" name="viewport"/>
#    <script id="config" type="application/json">
#     {"app_name":"open_page","isAnonymous":true}
#    </script>
#    <script id="baba" type="application/json">
#     []
#    </script>
#    <script async="" defer="" src="https://open.scdn.co/cdn/js/gtag.16935790.js">
#    </script>
#    <script id="fb-pixel" type="application/json">
#     {"url":"https://open.scdn.co/cdn/js/fb.83cf1e53.js"}
#    </script>
#    <script async="" defer="" src="https://www.googletagmanager.com/gtag/js?id=UA-5784146-31">
#    </script>
#    <link href="https://open.scdn.co/cdn/build/open/open.385f4c1b.css" rel="stylesheet"/>
#    <style type="text/css">
#    </style>
#    <link href="https://open.scdn.co/cdn/images/favicon.0c211e2e.png " rel="icon"/>
#    <link href="https://open.scdn.co/cdn/images/touch-icon-144.36faaf96.png" rel="apple-touch-icon-precomposed" sizes="144x144"/>
#    <link href="https://open.scdn.co/cdn/images/touch-icon-114.0d424df2.png" rel="apple-touch-icon-precomposed" sizes="114x114"/>
#    <link href="https://open.scdn.co/cdn/images/touch-icon-72.cffecbdb.png" rel="apple-touch-icon-precomposed" sizes="72x72"/>
#    <link href="https://open.scdn.co/cdn/images/touch-icon-57.5460f415.png" rel="apple-touch-icon-precomposed"/>
#   </meta>
#  </head>
#  <body id="body">
#   <div class="page">
#    <script>
#     (function() {
#     var setFont = function() {
#         document.documentElement.className += ' fonts-loaded';
#     };
#     if (document.fonts && document.fonts.load) {
#         var fontsToLoad = ['200 1em \'spotify-circular\'', '600 1em \'spotify-circular\''];
#
#
#
#
#         Promise.all(
#             fontsToLoad.map(function(font) {
#                 return document.fonts.load(font);
#             })
#         ).then(setFont).catch(setFont);
#     } else {
#         setFont();
#     }
# })();
#    </script>
#    <svg style="display:none" xmlns="http://www.w3.org/2000/svg">
#     <symbol id="spotify-logo" viewbox="0 0 1000 300">
#      <path d="M8 147C8 65 73 0 155 0s148 65 148 147-66 148-148 148S8 229 8 147zm202 69c10 6 20-10 10-16-39-24-88-30-144-17-12 3-7 21 5 18 51-12 94-6 129 15zm15-40c13 8 25-11 12-19-46-28-112-36-166-20-14 4-7 26 7 22 47-14 107-7 147 17zM71 113c45-14 124-10 172 18 15 9 29-15 14-24-55-33-142-36-194-20-17 5-9 31 8 26zm308 4c0 9 4 13 30 19 31 8 44 19 44 40 0 25-19 42-49 42-21 0-40-8-56-22-1-1-1-1 0-2l14-17c1-1 1-1 2 0 14 12 26 17 41 17 13 0 22-6 22-15 0-8-5-13-29-19-29-7-45-16-45-41 0-24 19-40 47-40 19 0 35 5 49 16 1 1 1 2 0 3l-13 17c0 1-1 2-2 1-12-9-23-14-35-14s-20 7-20 15zm109 9c9-10 19-15 32-15 24 0 48 18 48 53s-24 54-48 54c-13 0-23-5-32-15v41c0 1-1 2-2 2h-22c-1 0-2-1-2-2V115c0-1 1-2 2-2h22c1 0 2 1 2 2v11zm27 69c16 0 27-13 27-31s-11-30-27-30-27 13-27 30 11 31 27 31zm60-30c0-30 24-54 55-54s55 23 55 53-24 54-55 54-55-23-55-53zm27-1c0 17 12 31 28 31 17 0 29-12 29-30 0-17-13-31-29-31s-28 12-28 30zm128 54c-20 0-31-10-31-31v-51h-11c-1 0-1-1-1-2v-19c0-1 0-2 1-2h11V87c0-1 1-1 2-1h23c1 0 2 0 2 1v26h25c1 0 1 1 1 2v19c0 1 0 2-1 2h-25v47c0 7 3 11 10 11 3 0 16-4 16-2v19c0 5-17 7-22 7zM865 78v19c0 3-12-1-15-1-8 0-12 5-12 14v3h39c1 0 2 0 2 1l27 70 24-70c0-1 1-1 2-1h23c1 0 2 1 2 2l-40 103c-8 21-17 29-34 29-3 0-27-4-25-9l7-17c0-1 2-2 3-1 4 2 8 4 12 4 5 0 9-2 13-10l-33-78h-21v78c0 1-1 2-2 2h-23c-1 0-1-1-1-2v-78h-11c-1 0-2-1-2-2v-20c0-1 1-1 2-1h11v-5c0-22 11-34 32-34 7 0 20 1 20 4zm-100 35h23c1 0 1 1 1 2v99c0 1 0 2-1 2h-23c-1 0-2-1-2-2v-99c0-1 1-2 2-2zm-5-29c0-9 7-16 16-16s17 7 17 16-8 16-17 16-16-7-16-16zm200 45c0-9 7-16 16-16s17 7 17 16-8 16-17 16-16-7-16-16zm2 0c0 8 6 14 14 14s15-6 15-14-7-15-15-15-14 7-14 15zm23 8h-4l-4-6h-4v6h-3v-17h7c4 0 7 2 7 5s-2 4-4 5zm-12-14v5h4c2 0 4-1 4-3s-2-2-4-2h-4z" fill="currentColor">
#      </path>
#     </symbol>
#     <symbol id="icon-play" viewbox="0 0 85 100">
#      <path d="M81 44.6c5 3 5 7.8 0 10.8L9 98.7c-5 3-9 .7-9-5V6.3c0-5.7 4-8 9-5l72 43.3z" fill="currentColor">
#      </path>
#     </symbol>
#     <symbol id="icon-pause" viewbox="0 0 60 100">
#      <path d="M0 8c0-5 3-8 8-8s9 3 9 8v84c0 5-4 8-9 8s-8-3-8-8V8zm43 0c0-5 3-8 8-8s8 3 8 8v84c0 5-3 8-8 8s-8-3-8-8V8z" fill="currentColor">
#      </path>
#     </symbol>
#     <symbol id="icon-explicit" viewbox="0 0 20 20">
#      <path d="M9 9V7h4V5H7v10h6v-2H9v-2h4V9H9zM0 2.994C0 1.34 1.343 0 2.994 0h14.012C18.66 0 20 1.343 20 2.994v14.012C20 18.66 18.657 20 17.006 20H2.994C1.34 20 0 18.657 0 17.006V2.994z" fill="currentColor">
#      </path>
#     </symbol>
#     <symbol id="icon-close" viewbox="0 0 2016 2016">
#      <path d="M1681 1512q35 35 35 84.5t-35 84.5-84.5 35-84.5-35l-504-504-504 504q-35 35-84.5 35t-84.5-35-35-84.5 35-84.5l504-504-504-504q-35-35-35-84.5t35-84.5q34-35 84-35 51 0 85 35l504 504 504-504q34-35 85-35 50 0 84 35 35 35 35 84.5t-35 84.5l-504 504 504 504z" fill="currentColor">
#      </path>
#     </symbol>
#    </svg>
#    <div class="notice notice-info padding-notch" id="cookie-notice">
#     <p>
#      We and
#      <a href="https://www.spotify.com/us/legal/cookies-vendor-list/" rel="noopener" target="_blank">
#       our partners
#      </a>
#      use cookies to personalize your experience, to show you ads based on your interests, and for measurement and analytics purposes. By using our website and our services, you agree to our use of cookies as described in our
#      <a href="https://www.spotify.com/legal/cookies-policy/" rel="noopener" target="_blank">
#       Cookie Policy
#      </a>
#      .
#     </p>
#     <button aria-label="Close" type="button">
#      ×
#     </button>
#    </div>
#    <div class="notice notice-warning padding-notch" id="browser-support-notice">
#     <p>
#      This browser doesn't support Spotify Web Player.
#      <a href="https://support.spotify.com/using_spotify/the_basics/webplayer">
#       Switch browsers
#      </a>
#      or
#      <a href="https://www.spotify.com/download">
#       download Spotify
#      </a>
#      for your desktop.
#     </p>
#    </div>
#    <header style="background-color: #d82241">
#     <div class="overlay">
#     </div>
#     <div class="wrapper padding-notch">
#      <div id="main-header">
#       <a class="logo-link" href="/browse">
#        <svg>
#         <use xlink:href="#spotify-logo" xmlns:xlink="http://www.w3.org/1999/xlink">
#         </use>
#        </svg>
#       </a>
#      </div>
#      <div class="entity ">
#       <div class="entity-info media">
#        <div class="media-img">
#         <button aria-label="Play" class="cover-art light shadow actionable playable-context js-cover-art js-playable " data-preview="" data-track-type="cover-art" data-uri="spotify:playlist:37i9dQZEVXbMnZEatlMSiu">
#          <div class="cover-art-image" style="background-image:url(//charts-images.scdn.co/assets/locale_en/regional/daily/region_tw_large.jpg), linear-gradient(transparent,rgba(0,0,0,0.5)); background-color: #d82241">
#          </div>
#          <div class="cover-art-playback" dir="ltr">
#           <svg class="icon-play">
#            <use xlink:href="#icon-play" xmlns:xlink="http://www.w3.org/1999/xlink">
#            </use>
#           </svg>
#           <svg class="icon-pause">
#            <use xlink:href="#icon-pause" xmlns:xlink="http://www.w3.org/1999/xlink">
#            </use>
#           </svg>
#          </div>
#         </button>
#        </div>
#        <div class="media-bd">
#         <h1>
#          <span dir="auto">
#           Taiwan Top 50
#          </span>
#         </h1>
#         <h2>
#          By
#          <a href="/user/spotifycharts">
#           spotifycharts
#          </a>
#         </h2>
#         <p class="entity-long-description">
#          <span dir="auto">
#           Your daily update of the most played tracks in Taiwan right now.
#          </span>
#         </p>
#         <p class="text-silence entity-additional-info">
#          50 songs
#         </p>
#         <button class="btn btn-green entity-cta js-action-button" data-track-type="button-header">
#          <span class="js-action-label">
#           Play on Spotify
#          </span>
#         </button>
#        </div>
#       </div>
#       <div class="tracklist-container">
#        <ol class="tracklist js-track-list playable-context ">
#         <li class="tracklist-row js-track-row tracklist-row--track track-has-preview" data-position="1" role="button" tabindex="0">
#          <div class="tracklist-col position-outer">
#           <div class="play-pause top-align">
#            <svg aria-label="Play" class="svg-play" role="button">
#             <use xlink:href="#icon-play" xmlns:xlink="http://www.w3.org/1999/xlink">
#             </use>
#            </svg>
#            <svg aria-label="Pause" class="svg-pause" role="button">
#             <use xlink:href="#icon-pause" xmlns:xlink="http://www.w3.org/1999/xlink">
#             </use>
#            </svg>
#           </div>
#           <div class="tracklist-col__track-number position top-align">
#            1.
#           </div>
#          </div>
#          <div class="tracklist-col name">
#           <div class="top-align track-name-wrapper">
#            <span class="track-name" dir="auto">
#             刻在我心底的名字 (Your Name Engraved Herein) - 電影&lt;刻在你心底的名字&gt;主題曲
#            </span>
#            <span class="artists-albums">
#             <a href="/artist/2JBUyLiFvpFPWdZGqIGYLD" tabindex="-1">
#              <span dir="auto">
#               Crowd Lu
#              </span>
#             </a>
#             •
#             <a href="/album/5RG4bEVKGMdLaEIv1dofR2" tabindex="-1">
#              <span dir="auto">
#               刻在我心底的名字 (Your Name Engraved Herein)
#              </span>
#             </a>
#            </span>
#           </div>
#          </div>
#          <div class="tracklist-col explicit">
#          </div>
#          <div class="tracklist-col duration">
#           <div class="top-align">
#            <span class="total-duration">
#             5:20
#            </span>
#            <span class="preview-duration">
#             0:30
#            </span>
#           </div>
#          </div>
#          <div class="progress-bar-outer">
#           <div class="progress-bar">
#           </div>
#          </div>
#         </li>
#         <li class="tracklist-row js-track-row tracklist-row--track track-has-preview" data-position="2" role="button" tabindex="0">
#          <div class="tracklist-col position-outer">
#           <div class="play-pause top-align">
#            <svg aria-label="Play" class="svg-play" role="button">
#             <use xlink:href="#icon-play" xmlns:xlink="http://www.w3.org/1999/xlink">
#             </use>
#            </svg>
#            <svg aria-label="Pause" class="svg-pause" role="button">
#             <use xlink:href="#icon-pause" xmlns:xlink="http://www.w3.org/1999/xlink">
#             </use>
#            </svg>
#           </div>
#           <div class="tracklist-col__track-number position top-align">
#            2.
#           </div>
#          </div>
#          <div class="tracklist-col name">
#           <div class="top-align track-name-wrapper">
#            <span class="track-name" dir="auto">
#             Celebrity
#            </span>
#            <span class="artists-albums">
#             <a href="/artist/3HqSLMAZ3g3d5poNaI7GOU" tabindex="-1">
#              <span dir="auto">
#               IU
#              </span>
#             </a>
#             •
#             <a href="/album/3mtDgtcl4bxDN73kIM216g" tabindex="-1">
#              <span dir="auto">
#               Celebrity
#              </span>
#             </a>
#            </span>
#           </div>
#          </div>
#          <div class="tracklist-col explicit">
#          </div>
#          <div class="tracklist-col duration">
#           <div class="top-align">
#            <span class="total-duration">
#             3:15
#            </span>
#            <span class="preview-duration">
#             0:30
#            </span>
#           </div>
#          </div>
#          <div class="progress-bar-outer">
#           <div class="progress-bar">
#           </div>
#          </div>
#         </li>
#         <li class="tracklist-row js-track-row tracklist-row--track track-has-preview" data-position="3" role="button" tabindex="0">
#          <div class="tracklist-col position-outer">
#           <div class="play-pause top-align">
#            <svg aria-label="Play" class="svg-play" role="button">
#             <use xlink:href="#icon-play" xmlns:xlink="http://www.w3.org/1999/xlink">
#             </use>
#            </svg>
#            <svg aria-label="Pause" class="svg-pause" role="button">
#             <use xlink:href="#icon-pause" xmlns:xlink="http://www.w3.org/1999/xlink">
#             </use>
#            </svg>
#           </div>
#           <div class="tracklist-col__track-number position top-align">
#            3.
#           </div>
#          </div>
#          <div class="tracklist-col name">
#           <div class="top-align track-name-wrapper">
#            <span class="track-name" dir="auto">
#             飞鸟和蝉
#            </span>
#            <span class="artists-albums">
#             <a href="/artist/6f4srX54JFrLNK4aTJe2Sc" tabindex="-1">
#              <span dir="auto">
#               Ren Ran
#              </span>
#             </a>
#             •
#             <a href="/album/4wQT3Fwlf2hxFpb0lEoyhf" tabindex="-1">
#              <span dir="auto">
#               飞鸟和蝉
#              </span>
#             </a>
#            </span>
#           </div>
#          </div>
#          <div class="tracklist-col explicit">
#          </div>
#          <div class="tracklist-col duration">
#           <div class="top-align">
#            <span class="total-duration">
#             4:56
#            </span>
#            <span class="preview-duration">
#             0:30
#            </span>
#           </div>
#          </div>
#          <div class="progress-bar-outer">
#           <div class="progress-bar">
#           </div>
#          </div>
#         </li>
#         <li class="tracklist-row js-track-row tracklist-row--track track-has-preview" data-position="4" role="button" tabindex="0">
#          <div class="tracklist-col position-outer">
#           <div class="play-pause top-align">
#            <svg aria-label="Play" class="svg-play" role="button">
#             <use xlink:href="#icon-play" xmlns:xlink="http://www.w3.org/1999/xlink">
#             </use>
#            </svg>
#            <svg aria-label="Pause" class="svg-pause" role="button">
#             <use xlink:href="#icon-pause" xmlns:xlink="http://www.w3.org/1999/xlink">
#             </use>
#            </svg>
#           </div>
#           <div class="tracklist-col__track-number position top-align">
#            4.
#           </div>
#          </div>
#          <div class="tracklist-col name">
#           <div class="top-align track-name-wrapper">
#            <span class="track-name" dir="auto">
#             想見你想見你想見你(電視劇"想見你"片尾曲)
#            </span>
#            <span class="artists-albums">
#             <a href="/artist/3TtgOeQcNkf9WVDA4xPBJM" tabindex="-1">
#              <span dir="auto">
#               831
#              </span>
#             </a>
#             •
#             <a href="/album/44M14sRDzNZBtfaSH9Au3i" tabindex="-1">
#              <span dir="auto">
#               想見你想見你想見你(電視劇"想見你"片尾曲)
#              </span>
#             </a>
#            </span>
#           </div>
#          </div>
#          <div class="tracklist-col explicit">
#          </div>
#          <div class="tracklist-col duration">
#           <div class="top-align">
#            <span class="total-duration">
#             3:59
#            </span>
#            <span class="preview-duration">
#             0:30
#            </span>
#           </div>
#          </div>
#          <div class="progress-bar-outer">
#           <div class="progress-bar">
#           </div>
#          </div>
#         </li>
#         <li class="tracklist-row js-track-row tracklist-row--track track-has-preview" data-position="5" role="button" tabindex="0">
#          <div class="tracklist-col position-outer">
#           <div class="play-pause top-align">
#            <svg aria-label="Play" class="svg-play" role="button">
#             <use xlink:href="#icon-play" xmlns:xlink="http://www.w3.org/1999/xlink">
#             </use>
#            </svg>
#            <svg aria-label="Pause" class="svg-pause" role="button">
#             <use xlink:href="#icon-pause" xmlns:xlink="http://www.w3.org/1999/xlink">
#             </use>
#            </svg>
#           </div>
#           <div class="tracklist-col__track-number position top-align">
#            5.
#           </div>
#          </div>
#          <div class="tracklist-col name">
#           <div class="top-align track-name-wrapper">
#            <span class="track-name" dir="auto">
#             在這座城市遺失了你
#            </span>
#            <span class="artists-albums">
#             <a href="/artist/6xErgeZYatiaQ36SB5bvi8" tabindex="-1">
#              <span dir="auto">
#               告五人
#              </span>
#             </a>
#             •
#             <a href="/album/6Vss0GQqlLtD4k3lSXnYI5" tabindex="-1">
#              <span dir="auto">
#               運氣來得若有似無
#              </span>
#             </a>
#            </span>
#           </div>
#          </div>
#          <div class="tracklist-col explicit">
#          </div>
#          <div class="tracklist-col duration">
#           <div class="top-align">
#            <span class="total-duration">
#             5:57
#            </span>
#            <span class="preview-duration">
#             0:30
#            </span>
#           </div>
#          </div>
#          <div class="progress-bar-outer">
#           <div class="progress-bar">
#           </div>
#          </div>
#         </li>
#         <li class="tracklist-row js-track-row tracklist-row--track track-has-preview" data-position="6" role="button" tabindex="0">
#          <div class="tracklist-col position-outer">
#           <div class="play-pause top-align">
#            <svg aria-label="Play" class="svg-play" role="button">
#             <use xlink:href="#icon-play" xmlns:xlink="http://www.w3.org/1999/xlink">
#             </use>
#            </svg>
#            <svg aria-label="Pause" class="svg-pause" role="button">
#             <use xlink:href="#icon-pause" xmlns:xlink="http://www.w3.org/1999/xlink">
#             </use>
#            </svg>
#           </div>
#           <div class="tracklist-col__track-number position top-align">
#            6.
#           </div>
#          </div>
#          <div class="tracklist-col name">
#           <div class="top-align track-name-wrapper">
#            <span class="track-name" dir="auto">
#             怎麼了
#            </span>
#            <span class="artists-albums">
#             <a href="/artist/5fEQLwq1BWWQNR8GzhOIvi" tabindex="-1">
#              <span dir="auto">
#               Eric Chou
#              </span>
#             </a>
#             •
#             <a href="/album/2lrmHLTedOpdP6TaZDZ77F" tabindex="-1">
#              <span dir="auto">
#               終於了解自由 (Deluxe)
#              </span>
#             </a>
#            </span>
#           </div>
#          </div>
#          <div class="tracklist-col explicit">
#          </div>
#          <div class="tracklist-col duration">
#           <div class="top-align">
#            <span class="total-duration">
#             5:21
#            </span>
#            <span class="preview-duration">
#             0:30
#            </span>
#           </div>
#          </div>
#          <div class="progress-bar-outer">
#           <div class="progress-bar">
#           </div>
#          </div>
#         </li>
#         <li class="tracklist-row js-track-row tracklist-row--track track-has-preview" data-position="7" role="button" tabindex="0">
#          <div class="tracklist-col position-outer">
#           <div class="play-pause top-align">
#            <svg aria-label="Play" class="svg-play" role="button">
#             <use xlink:href="#icon-play" xmlns:xlink="http://www.w3.org/1999/xlink">
#             </use>
#            </svg>
#            <svg aria-label="Pause" class="svg-pause" role="button">
#             <use xlink:href="#icon-pause" xmlns:xlink="http://www.w3.org/1999/xlink">
#             </use>
#            </svg>
#           </div>
#           <div class="tracklist-col__track-number position top-align">
#            7.
#           </div>
#          </div>
#          <div class="tracklist-col name">
#           <div class="top-align track-name-wrapper">
#            <span class="track-name" dir="auto">
#             drivers license
#            </span>
#            <span class="artists-albums">
#             <a href="/artist/1McMsnEElThX1knmY4oliG" tabindex="-1">
#              <span dir="auto">
#               Olivia Rodrigo
#              </span>
#             </a>
#             •
#             <a href="/album/66FPnVL9G4CMKy3wvaGTcr" tabindex="-1">
#              <span dir="auto">
#               drivers license
#              </span>
#             </a>
#            </span>
#           </div>
#          </div>
#          <div class="tracklist-col explicit">
#           <div class="top-align">
#            <svg class="icon-explicit" title="Explicit">
#             <use xlink:href="#icon-explicit" xmlns:xlink="http://www.w3.org/1999/xlink">
#             </use>
#            </svg>
#           </div>
#          </div>
#          <div class="tracklist-col duration">
#           <div class="top-align">
#            <span class="total-duration">
#             4:02
#            </span>
#            <span class="preview-duration">
#             0:30
#            </span>
#           </div>
#          </div>
#          <div class="progress-bar-outer">
#           <div class="progress-bar">
#           </div>
#          </div>
#         </li>
#         <li class="tracklist-row js-track-row tracklist-row--track track-has-preview" data-position="8" role="button" tabindex="0">
#          <div class="tracklist-col position-outer">
#           <div class="play-pause top-align">
#            <svg aria-label="Play" class="svg-play" role="button">
#             <use xlink:href="#icon-play" xmlns:xlink="http://www.w3.org/1999/xlink">
#             </use>
#            </svg>
#            <svg aria-label="Pause" class="svg-pause" role="button">
#             <use xlink:href="#icon-pause" xmlns:xlink="http://www.w3.org/1999/xlink">
#             </use>
#            </svg>
#           </div>
#           <div class="tracklist-col__track-number position top-align">
#            8.
#           </div>
#          </div>
#          <div class="tracklist-col name">
#           <div class="top-align track-name-wrapper">
#            <span class="track-name" dir="auto">
#             Dynamite
#            </span>
#            <span class="artists-albums">
#             <a href="/artist/3Nrfpe0tUJi4K4DXYWgMUX" tabindex="-1">
#              <span dir="auto">
#               BTS
#              </span>
#             </a>
#             •
#             <a href="/album/2qehskW9lYGWfYb0xPZkrS" tabindex="-1">
#              <span dir="auto">
#               BE
#              </span>
#             </a>
#            </span>
#           </div>
#          </div>
#          <div class="tracklist-col explicit">
#          </div>
#          <div class="tracklist-col duration">
#           <div class="top-align">
#            <span class="total-duration">
#             3:19
#            </span>
#            <span class="preview-duration">
#             0:30
#            </span>
#           </div>
#          </div>
#          <div class="progress-bar-outer">
#           <div class="progress-bar">
#           </div>
#          </div>
#         </li>
#         <li class="tracklist-row js-track-row tracklist-row--track track-has-preview" data-position="9" role="button" tabindex="0">
#          <div class="tracklist-col position-outer">
#           <div class="play-pause top-align">
#            <svg aria-label="Play" class="svg-play" role="button">
#             <use xlink:href="#icon-play" xmlns:xlink="http://www.w3.org/1999/xlink">
#             </use>
#            </svg>
#            <svg aria-label="Pause" class="svg-pause" role="button">
#             <use xlink:href="#icon-pause" xmlns:xlink="http://www.w3.org/1999/xlink">
#             </use>
#            </svg>
#           </div>
#           <div class="tracklist-col__track-number position top-align">
#            9.
#           </div>
#          </div>
#          <div class="tracklist-col name">
#           <div class="top-align track-name-wrapper">
#            <span class="track-name" dir="auto">
#             因為你 所以我
#            </span>
#            <span class="artists-albums">
#             <a href="/artist/16s0YTFcyjP4kgFwt7ktrY" tabindex="-1">
#              <span dir="auto">
#               Mayday
#              </span>
#             </a>
#             •
#             <a href="/album/0bLc2MyuEEP8eiMnd6v5Rt" tabindex="-1">
#              <span dir="auto">
#               因為你 所以我
#              </span>
#             </a>
#            </span>
#           </div>
#          </div>
#          <div class="tracklist-col explicit">
#          </div>
#          <div class="tracklist-col duration">
#           <div class="top-align">
#            <span class="total-duration">
#             4:41
#            </span>
#            <span class="preview-duration">
#             0:30
#            </span>
#           </div>
#          </div>
#          <div class="progress-bar-outer">
#           <div class="progress-bar">
#           </div>
#          </div>
#         </li>
#         <li class="tracklist-row js-track-row tracklist-row--track track-has-preview" data-position="10" role="button" tabindex="0">
#          <div class="tracklist-col position-outer">
#           <div class="play-pause top-align">
#            <svg aria-label="Play" class="svg-play" role="button">
#             <use xlink:href="#icon-play" xmlns:xlink="http://www.w3.org/1999/xlink">
#             </use>
#            </svg>
#            <svg aria-label="Pause" class="svg-pause" role="button">
#             <use xlink:href="#icon-pause" xmlns:xlink="http://www.w3.org/1999/xlink">
#             </use>
#            </svg>
#           </div>
#           <div class="tracklist-col__track-number position top-align">
#            10.
#           </div>
#          </div>
#          <div class="tracklist-col name">
#           <div class="top-align track-name-wrapper">
#            <span class="track-name" dir="auto">
#             炎
#            </span>
#            <span class="artists-albums">
#             <a href="/artist/0blbVefuxOGltDBa00dspv" tabindex="-1">
#              <span dir="auto">
#               LiSA
#              </span>
#             </a>
#             •
#             <a href="/album/1KmL1EZ0Pg9Vj3rPYMDqHY" tabindex="-1">
#              <span dir="auto">
#               炎
#              </span>
#             </a>
#            </span>
#           </div>
#          </div>
#          <div class="tracklist-col explicit">
#          </div>
#          <div class="tracklist-col duration">
#           <div class="top-align">
#            <span class="total-duration">
#             4:35
#            </span>
#            <span class="preview-duration">
#             0:30
#            </span>
#           </div>
#          </div>
#          <div class="progress-bar-outer">
#           <div class="progress-bar">
#           </div>
#          </div>
#         </li>
#         <li class="tracklist-row js-track-row tracklist-row--track " data-position="11" role="button" tabindex="0">
#          <div class="tracklist-col position-outer">
#           <div class="play-pause top-align">
#            <svg aria-label="Play" class="svg-play" role="button">
#             <use xlink:href="#icon-play" xmlns:xlink="http://www.w3.org/1999/xlink">
#             </use>
#            </svg>
#            <svg aria-label="Pause" class="svg-pause" role="button">
#             <use xlink:href="#icon-pause" xmlns:xlink="http://www.w3.org/1999/xlink">
#             </use>
#            </svg>
#           </div>
#           <div class="tracklist-col__track-number position top-align">
#            11.
#           </div>
#          </div>
#          <div class="tracklist-col name">
#           <div class="top-align track-name-wrapper">
#            <span class="track-name" dir="auto">
#             她沒在看我
#            </span>
#            <span class="artists-albums">
#             <a href="/artist/2qXGNIlmY3JrYkxOWyXZsd" tabindex="-1">
#              <span dir="auto">
#               E.SO
#              </span>
#             </a>
#             •
#             <a href="/album/5qiMTeDKaY3cfqZeBG0xUY" tabindex="-1">
#              <span dir="auto">
#               Outta Body靈魂出竅
#              </span>
#             </a>
#            </span>
#           </div>
#          </div>
#          <div class="tracklist-col explicit">
#          </div>
#          <div class="tracklist-col duration">
#           <div class="top-align">
#            <span class="total-duration">
#             2:58
#            </span>
#            <span class="preview-duration">
#             0:30
#            </span>
#           </div>
#          </div>
#          <div class="progress-bar-outer">
#           <div class="progress-bar">
#           </div>
#          </div>
#         </li>
#         <li class="tracklist-row js-track-row tracklist-row--track track-has-preview" data-position="12" role="button" tabindex="0">
#          <div class="tracklist-col position-outer">
#           <div class="play-pause top-align">
#            <svg aria-label="Play" class="svg-play" role="button">
#             <use xlink:href="#icon-play" xmlns:xlink="http://www.w3.org/1999/xlink">
#             </use>
#            </svg>
#            <svg aria-label="Pause" class="svg-pause" role="button">
#             <use xlink:href="#icon-pause" xmlns:xlink="http://www.w3.org/1999/xlink">
#             </use>
#            </svg>
#           </div>
#           <div class="tracklist-col__track-number position top-align">
#            12.
#           </div>
#          </div>
#          <div class="tracklist-col name">
#           <div class="top-align track-name-wrapper">
#            <span class="track-name" dir="auto">
#             平凡天使
#            </span>
#            <span class="artists-albums">
#             <a href="/artist/7aRC4L63dBn3CiLDuWaLSI" tabindex="-1">
#              <span dir="auto">
#               G.E.M.
#              </span>
#             </a>
#             •
#             <a href="/album/6dOrr1HwvFh5vg1PKP4z4K" tabindex="-1">
#              <span dir="auto">
#               平凡天使
#              </span>
#             </a>
#            </span>
#           </div>
#          </div>
#          <div class="tracklist-col explicit">
#          </div>
#          <div class="tracklist-col duration">
#           <div class="top-align">
#            <span class="total-duration">
#             3:33
#            </span>
#            <span class="preview-duration">
#             0:30
#            </span>
#           </div>
#          </div>
#          <div class="progress-bar-outer">
#           <div class="progress-bar">
#           </div>
#          </div>
#         </li>
#         <li class="tracklist-row js-track-row tracklist-row--track track-has-preview" data-position="13" role="button" tabindex="0">
#          <div class="tracklist-col position-outer">
#           <div class="play-pause top-align">
#            <svg aria-label="Play" class="svg-play" role="button">
#             <use xlink:href="#icon-play" xmlns:xlink="http://www.w3.org/1999/xlink">
#             </use>
#            </svg>
#            <svg aria-label="Pause" class="svg-pause" role="button">
#             <use xlink:href="#icon-pause" xmlns:xlink="http://www.w3.org/1999/xlink">
#             </use>
#            </svg>
#           </div>
# ...
#             </use>
#            </svg>
#            <svg aria-label="Pause" class="svg-pause" role="button">
#             <use xlink:href="#icon-pause" xmlns:xlink="http://www.w3.org/1999/xlink">
#             </use>
#            </svg>
#           </div>
#           <div class="tracklist-col__track-number position top-align">
#            28.
#           </div>
#          </div>
#          <div class="tracklist-col name">
#           <div class="top-align track-name-wrapper">
#            <span class="track-name" dir="auto">
#             少年
#            </span>
#            <span class="artists-albums">
#             <a href="/artist/6taSlFSqCqAEUHOliFyHt7" tabindex="-1">
#              <span dir="auto">
#               梦然
#              </span>
#             </a>
#             •
#             <a href="/album/5bXN7segGUJUfO1DvQ4QN2" tabindex="-1">
#              <span dir="auto">
#               少年
#              </span>
#             </a>
#            </span>
#           </div>
#          </div>
#          <div class="tracklist-col explicit">
#          </div>
#          <div class="tracklist-col duration">
#           <div class="top-align">
#            <span class="total-duration">
#             3:56
#            </span>
#            <span class="preview-duration">
#             0:30
#            </span>
#           </div>
#          </div>
#          <div class="progress-bar-outer">
#           <div class="progress-bar">
#           </div>
#          </div>
#         </li>
#         <li class="tracklist-row js-track-row tracklist-row--track track-has-preview" data-position="29" role="button" tabindex="0">
#          <div class="tracklist-col position-outer">
#           <div class="play-pause top-align">
#            <svg aria-label="Play" class="svg-play" role="button">
#             <use xlink:href="#icon-play" xmlns:xlink="http://www.w3.org/1999/xlink">
#             </use>
#            </svg>
#            <svg aria-label="Pause" class="svg-pause" role="button">
#             <use xlink:href="#icon-pause" xmlns:xlink="http://www.w3.org/1999/xlink">
#             </use>
#            </svg>
#           </div>
#           <div class="tracklist-col__track-number position top-align">
#            29.
#           </div>
#          </div>
#          <div class="tracklist-col name">
#           <div class="top-align track-name-wrapper">
#            <span class="track-name" dir="auto">
#             Monster (Shawn Mendes &amp; Justin Bieber)
#            </span>
#            <span class="artists-albums">
#             <a href="/artist/7n2wHs1TKAczGzO7Dd2rGr" tabindex="-1">
#              <span dir="auto">
#               Shawn Mendes
#              </span>
#             </a>
#             ,
#             <a href="/artist/1uNFoZAHBGtllmzznpCI3s" tabindex="-1">
#              <span dir="auto">
#               Justin Bieber
#              </span>
#             </a>
#             •
#             <a href="/album/3Lp4JKk2ZgNkybMRS3eZR5" tabindex="-1">
#              <span dir="auto">
#               Wonder
#              </span>
#             </a>
#            </span>
#           </div>
#          </div>
#          <div class="tracklist-col explicit">
#          </div>
#          <div class="tracklist-col duration">
#           <div class="top-align">
#            <span class="total-duration">
#             2:58
#            </span>
#            <span class="preview-duration">
#             0:30
#            </span>
#           </div>
#          </div>
#          <div class="progress-bar-outer">
#           <div class="progress-bar">
#           </div>
#          </div>
#         </li>
#         <li class="tracklist-row js-track-row tracklist-row--track track-has-preview" data-position="30" role="button" tabindex="0">
#          <div class="tracklist-col position-outer">
#           <div class="play-pause top-align">
#            <svg aria-label="Play" class="svg-play" role="button">
#             <use xlink:href="#icon-play" xmlns:xlink="http://www.w3.org/1999/xlink">
#             </use>
#            </svg>
#            <svg aria-label="Pause" class="svg-pause" role="button">
#             <use xlink:href="#icon-pause" xmlns:xlink="http://www.w3.org/1999/xlink">
#             </use>
#            </svg>
#           </div>
#           <div class="tracklist-col__track-number position top-align">
#            30.
#           </div>
#          </div>
#          <div class="tracklist-col name">
#           <div class="top-align track-name-wrapper">
#            <span class="track-name" dir="auto">
#             他們說我是沒有用的年輕人
#            </span>
#            <span class="artists-albums">
#             <a href="/artist/4xlAHgZnzzPHtoKnev0gwJ" tabindex="-1">
#              <span dir="auto">
#               Good Band
#              </span>
#             </a>
#             •
#             <a href="/album/52wbyXpG9wiklOacpLGrig" tabindex="-1">
#              <span dir="auto">
#               他們說我是沒有用的年輕人
#              </span>
#             </a>
#            </span>
#           </div>
#          </div>
#          <div class="tracklist-col explicit">
#          </div>
#          <div class="tracklist-col duration">
#           <div class="top-align">
#            <span class="total-duration">
#             5:23
#            </span>
#            <span class="preview-duration">
#             0:30
#            </span>
#           </div>
#          </div>
#          <div class="progress-bar-outer">
#           <div class="progress-bar">
#           </div>
#          </div>
#         </li>
#        </ol>
#        <button class="link js-action-button" data-track-type="view-all-button">
#         View all on Spotify
#        </button>
#       </div>
#      </div>
#     </div>
#    </header>
#    <section class="more-by">
#     <div class="btn-scroll-wrapper">
#      <a class="btn-scroll" href="#upsell" tabindex="-1">
#       <svg viewbox="0 0 80 80">
#        <path d="M40 42L73 6c4-4 10 1 6 6L43 49c-2 2-4 2-6 0L1 12C-3 8 4 2 8 6zm0 27l33-34c4-4 10 1 6 6L43 78c-2 2-4 2-6 0L1 41c-4-4 3-10 7-6z">
#        </path>
#       </svg>
#      </a>
#     </div>
#    </section>
#    <section class="upsell " id="upsell" style="background-color: #d82241">
#     <div class="overlay">
#     </div>
#     <div class="wrapper padding-notch">
#      <h1>
#       Listen to Taiwan Top 50 now.
#      </h1>
#      <p>
#       Listen to Taiwan Top 50 in full in the Spotify app
#      </p>
#      <button class="btn btn-green js-action-button" data-track-type="button-footer">
#       <span class="js-action-label">
#        Play on Spotify
#       </span>
#      </button>
#     </div>
#    </section>
#    <footer>
#     <a class="logo-link" href="/browse">
#      <svg>
#       <use xlink:href="#spotify-logo" xmlns:xlink="http://www.w3.org/1999/xlink">
#       </use>
#      </svg>
#     </a>
#     <p class="legal">
#      <a href="https://www.spotify.com/legal/" rel="noopener" target="_blank">
#       Legal
#      </a>
#      <br/>
#      <a href="https://www.spotify.com/legal/privacy-policy/" rel="noopener" target="_blank">
#       Privacy
#      </a>
#      <br/>
#      <a href="https://www.spotify.com/legal/cookies-policy/" rel="noopener" target="_blank">
#       Cookies
#      </a>
#      <br/>
#      <a href="https://www.spotify.com/legal/privacy-policy/#s3" rel="noopener" target="_blank">
#       About Ads
#      </a>
#     </p>
#    </footer>
#   </div>
#   <div aria-hidden="true" aria-labelledby="choice-modal-title" class="choice-modal js-choice-modal hide" role="dialog">
#    <div class="choice-modal-inner">
#     <button aria-label="Close" class="btn-close">
#      <svg>
#       <use xlink:href="#icon-close" xmlns:xlink="http://www.w3.org/1999/xlink">
#       </use>
#      </svg>
#     </button>
#     <span class="modal-title" id="choice-modal-title">
#      To play this content, you'll need the Spotify app.
#     </span>
#     <div class="wrapper-btn">
#      <button class="btn btn-green" id="mobile-download" type="button">
#       Get Spotify
#      </button>
#      <button class="btn btn-transparent" id="mobile-play" type="button">
#       Open Spotify
#      </button>
#     </div>
#    </div>
#   </div>
#   <div aria-hidden="true" aria-labelledby="upsell-modal-title" class="upsell-modal js-upsell-modal hide" role="dialog">
#    <button aria-label="Close" class="btn-close">
#     <svg>
#      <use xlink:href="#icon-close" xmlns:xlink="http://www.w3.org/1999/xlink">
#      </use>
#     </svg>
#    </button>
#    <h3 id="upsell-modal-title">
#     You look like someone who appreciates good music.
#    </h3>
#    <p>
#     Listen to all your favourite artists on any device for free or try the Premium trial.
#    </p>
#    <button class="link">
#     Play on Spotify
#    </button>
#   </div>
#   <script data-testid="spotify-environment">
#    window.SpotifyEnvironment = {
#         autoplay: JSON.parse("false"),
#         context: {
#             uri: "spotify:playlist:37i9dQZEVXbMnZEatlMSiu",
#                         type: null
#         },
#         strings: {
#             'Download Spotify': "Download Spotify",
#             'Play on Spotify': "Play on Spotify",
#             'View on Spotify': "View on Spotify",
#             'Follow on Spotify': "Follow on Spotify"
#         },
#         platform: "desktop",
#         isMobile: false,
#         isBrowserSupportedInWebPlayer: false,
#         usesWebPlayer: false,
#         isSpotified: false,
#                 downloadLink: "https://www.spotify.com/signup/?creation_flow=open&utm_source=open",
#                 environment: "production",
#                 features: {
#                                 }
#     };
#   </script>
#   <script>
#    Spotify = {};
# 				Spotify.Entity = {"collaborative":false,"description":"Your daily update of the most played tracks in Taiwan right now.","external_urls":{"spotify":"https:\/\/open.spotify.com\/playlist\/37i9dQZEVXbMnZEatlMSiu"},"followers":{"href":null,"total":166769},"href":"https:\/\/api.spotify.com\/v1\/playlists\/37i9dQZEVXbMnZEatlMSiu?type=track%2Cepisode","id":"37i9dQZEVXbMnZEatlMSiu","images":[{"height":null,"url":"https:\/\/charts-images.scdn.co\/assets\/locale_en\/regional\/daily\/region_tw_large.jpg","width":null}],"name":"Taiwan Top 50","owner":{"display_name":"spotifycharts","external_urls":{"spotify":"https:\/\/open.spotify.com\/user\/spotifycharts"},"href":"https:\/\/api.spotify.com\/v1\/users\/spotifycharts","id":"spotifycharts","type":"user","uri":"spotify:user:spotifycharts"},"primary_color":null,"public":false,"snapshot_id":"NjY1Njg5NDc4LDAwMDAwMDAwMDAwMDAwMDAwMDAwMDAwMDAwMDAwMDAwMDAwMDY1NmU=","tracks":{"href":"https:\/\/api.spotify.com\/v1\/playlists\/37i9dQZEVXbMnZEatlMSiu\/tracks?offset=0&limit=100&market=US&locale=en&type=track%2Cepisode","items":[{"added_at":"1970-01-01T00:00:00Z","added_by":{"external_urls":{"spotify":"https:\/\/open.spotify.com\/user\/"},"href":"https:\/\/api.spotify.com\/v1\/users\/","id":"","type":"user","uri":"spotify:user:"},"is_local":false,"primary_color":null,"track":{"album":{"album_type":"single","artists":[{"external_urls":{"spotify":"https:\/\/open.spotify.com\/artist\/2JBUyLiFvpFPWdZGqIGYLD"},"href":"https:\/\/api.spotify.com\/v1\/artists\/2JBUyLiFvpFPWdZGqIGYLD","id":"2JBUyLiFvpFPWdZGqIGYLD","name":"Crowd Lu","type":"artist","uri":"spotify:artist:2JBUyLiFvpFPWdZGqIGYLD"}],"external_urls":{"spotify":"https:\/\/open.spotify.com\/album\/5RG4bEVKGMdLaEIv1dofR2"},"href":"https:\/\/api.spotify.com\/v1\/albums\/5RG4bEVKGMdLaEIv1dofR2","id":"5RG4bEVKGMdLaEIv1dofR2","images":[{"height":640,"url":"https:\/\/i.scdn.co\/image\/ab67616d0000b273a09d99cdbfdb0fafee0c2318","width":640},{"height":300,"url":"https:\/\/i.scdn.co\/image\/ab67616d00001e02a09d99cdbfdb0fafee0c2318","width":300},{"height":64,"url":"https:\/\/i.scdn.co\/image\/ab67616d00004851a09d99cdbfdb0fafee0c2318","width":64}],"name":"\u523b\u5728\u6211\u5fc3\u5e95\u7684\u540d\u5b57 (Your Name Engraved Herein)","release_date":"2020-08-25","release_date_precision":"day","total_tracks":1,"type":"album","uri":"spotify:album:5RG4bEVKGMdLaEIv1dofR2"},"artists":[{"external_urls":{"spotify":"https:\/\/open.spotify.com\/artist\/2JBUyLiFvpFPWdZGqIGYLD"},"href":"https:\/\/api.spotify.com\/v1\/artists\/2JBUyLiFvpFPWdZGqIGYLD","id":"2JBUyLiFvpFPWdZGqIGYLD","name":"Crowd Lu","type":"artist","uri":"spotify:artist:2JBUyLiFvpFPWdZGqIGYLD"}],"disc_number":1,"duration_ms":320165,"episode":false,"explicit":false,"external_ids":{"isrc":"TWK012000002"},"external_urls":{"spotify":"https:\/\/open.spotify.com\/track\/3OC84eKMxRJ4x0Hcwl9i4i"},"href":"https:\/\/api.spotify.com\/v1\/tracks\/3OC84eKMxRJ4x0Hcwl9i4i","id":"3OC84eKMxRJ4x0Hcwl9i4i","is_local":false,"is_playable":true,"name":"\u523b\u5728\u6211\u5fc3\u5e95\u7684\u540d\u5b57 (Your Name Engraved Herein) - \u96fb\u5f71<\u523b\u5728\u4f60\u5fc3\u5e95\u7684\u540d\u5b57>\u4e3b\u984c\u66f2","popularity":72,"preview_url":"https:\/\/p.scdn.co\/mp3-preview\/c5707d25e6bc0f67df3bc0ca7bf611cf8d72b6cb?cid=162b7dc01f3a4a2ca32ed3cec83d1e02","track":true,"track_number":1,"type":"track","uri":"spotify:track:3OC84eKMxRJ4x0Hcwl9i4i"},"video_thumbnail":{"url":null}},{"added_at":"1970-01-01T00:00:00Z","added_by":{"external_urls":{"spotify":"https:\/\/open.spotify.com\/user\/"},"href":"https:\/\/api.spotify.com\/v1\/users\/","id":"","type":"user","uri":"spotify:user:"},"is_local":false,"primary_color":null,"track":{"album":{"album_type":"single","artists":[{"external_urls":{"spotify":"https:\/\/open.spotify.com\/artist\/3HqSLMAZ3g3d5poNaI7GOU"},"href":"https:\/\/api.spotify.com\/v1\/artists\/3HqSLMAZ3g3d5poNaI7GOU","id":"3HqSLMAZ3g3d5poNaI7GOU","name":"IU","type":"artist","uri":"spotify:artist:3HqSLMAZ3g3d5poNaI7GOU"}],"externa ...
#   </script>
#   <script async="" src="https://open.scdn.co/cdn/build/open/open.85666876.js">
#   </script>
#   <script async="" src="https://open.scdn.co/cdn/build/open/vendor~open.dff6d1b4.js">
#   </script>
#   <script>
#    (function() {
#     var timeout = 5000;
#     function loadFbPixel () {
#         !(function (f, b, e, v, n, t, s) {
#         if (f.fbq) return;
#         n = f.fbq = function () {
#             n.callMethod ? n.callMethod.apply(n, arguments) : n.queue.push(arguments);
#         };
#         if (!f._fbq) f._fbq = n;
#         n.push = n;
#         n.loaded = !0;
#         n.version = '2.0';
#         n.queue = [];
#         t = b.createElement(e);
#         t.async = !0;
#         t.src = v;
#         s = b.getElementsByTagName(e)[0];
#         s.parentNode.insertBefore(t, s);
#         })(
#         window,
#         document,
#         'script',
#         'https://connect.facebook.net/en_US/fbevents.js',
#         );
#
#         fbq('init', '1483047915331997');
#         fbq('track', 'PageView');
#     }
#     if (window.requestIdleCallback) {
#         window.requestIdleCallback(loadFbPixel, {timeout: timeout});
#     } else {
#         setTimeout(loadFbPixel, timeout);
#     }
# })();
#   </script>
#   <!-- Begin comScore Tag -->
#   <script>
#    var _comscore = _comscore || [];
# _comscore.push({ c1: "2", c2: "15654041" });
# (function() {
#   var s = document.createElement("script"), el =
#     document.getElementsByTagName("script")[0]; s.async = true;
#   s.src = "https://sb.scorecardresearch.com/beacon.js";
#   el.parentNode.insertBefore(s, el);
# })();
#   </script>
#   <!-- End comScore Tag -->
#   <script>
#    function getCookie(name) {
#   const v = document.cookie.match(`(^|;) ?${name}=([^;]*)(;|$)`);
#   return v ? v[2] : null;
# }
#
# const isQualaroo = getCookie('qualarooTimer');
# if (isQualaroo) {
#   window._kiq = window._kiq || [];
#   (function() {
#     setTimeout(function() {
#       const d = document;
#       const f = d.getElementsByTagName('script')[0];
#       const s = d.createElement('script');
#       s.type = 'text/javascript';
#       s.async = true;
#       s.src = '//s3.amazonaws.com/ki.js/51746/b0R.js';
#       s.addEventListener('load', function() {
#         const spcid = getCookie('sp_t');
#         window._kiq.push(['identify', spcid]);
#       });
#       f.parentNode.insertBefore(s, f);
#     }, 1);
#   })();
# }
#
# (function () {
#   var buttons = {
#     "mobile-login": 'login',
#     "mobile-continue-on-web": 'signup',
#     "mobile-download": 'download-app',
#   };
#
#   for (var key of Object.keys(buttons)) {
#     var button = document.getElementById(key)
#     if (button) {
#       button.addEventListener('click', function(e) {
#         gtag('event', buttons[e.target.id], {
#           'event_category': 'click',
#           'event_label': '/button',
#           'value': null,
#         });
#       });
#     }
#   }
# })();
#   </script>
#  </body>
# </html>

# %%
data1 = html_doc.find("div")
print(data1)
# Out:
# <div class="page"><script>
# (function() {
#     var setFont = function() {
#         document.documentElement.className += ' fonts-loaded';
#     };
#     if (document.fonts && document.fonts.load) {
#         var fontsToLoad = ['200 1em \'spotify-circular\'', '600 1em \'spotify-circular\''];
#
#
#
#
#         Promise.all(
#             fontsToLoad.map(function(font) {
#                 return document.fonts.load(font);
#             })
#         ).then(setFont).catch(setFont);
#     } else {
#         setFont();
#     }
# })();
# </script><svg style="display:none" xmlns="http://www.w3.org/2000/svg"><symbol id="spotify-logo" viewbox="0 0 1000 300"><path d="M8 147C8 65 73 0 155 0s148 65 148 147-66 148-148 148S8 229 8 147zm202 69c10 6 20-10 10-16-39-24-88-30-144-17-12 3-7 21 5 18 51-12 94-6 129 15zm15-40c13 8 25-11 12-19-46-28-112-36-166-20-14 4-7 26 7 22 47-14 107-7 147 17zM71 113c45-14 124-10 172 18 15 9 29-15 14-24-55-33-142-36-194-20-17 5-9 31 8 26zm308 4c0 9 4 13 30 19 31 8 44 19 44 40 0 25-19 42-49 42-21 0-40-8-56-22-1-1-1-1 0-2l14-17c1-1 1-1 2 0 14 12 26 17 41 17 13 0 22-6 22-15 0-8-5-13-29-19-29-7-45-16-45-41 0-24 19-40 47-40 19 0 35 5 49 16 1 1 1 2 0 3l-13 17c0 1-1 2-2 1-12-9-23-14-35-14s-20 7-20 15zm109 9c9-10 19-15 32-15 24 0 48 18 48 53s-24 54-48 54c-13 0-23-5-32-15v41c0 1-1 2-2 2h-22c-1 0-2-1-2-2V115c0-1 1-2 2-2h22c1 0 2 1 2 2v11zm27 69c16 0 27-13 27-31s-11-30-27-30-27 13-27 30 11 31 27 31zm60-30c0-30 24-54 55-54s55 23 55 53-24 54-55 54-55-23-55-53zm27-1c0 17 12 31 28 31 17 0 29-12 29-30 0-17-13-31-29-31s-28 12-28 30zm128 54c-20 0-31-10-31-31v-51h-11c-1 0-1-1-1-2v-19c0-1 0-2 1-2h11V87c0-1 1-1 2-1h23c1 0 2 0 2 1v26h25c1 0 1 1 1 2v19c0 1 0 2-1 2h-25v47c0 7 3 11 10 11 3 0 16-4 16-2v19c0 5-17 7-22 7zM865 78v19c0 3-12-1-15-1-8 0-12 5-12 14v3h39c1 0 2 0 2 1l27 70 24-70c0-1 1-1 2-1h23c1 0 2 1 2 2l-40 103c-8 21-17 29-34 29-3 0-27-4-25-9l7-17c0-1 2-2 3-1 4 2 8 4 12 4 5 0 9-2 13-10l-33-78h-21v78c0 1-1 2-2 2h-23c-1 0-1-1-1-2v-78h-11c-1 0-2-1-2-2v-20c0-1 1-1 2-1h11v-5c0-22 11-34 32-34 7 0 20 1 20 4zm-100 35h23c1 0 1 1 1 2v99c0 1 0 2-1 2h-23c-1 0-2-1-2-2v-99c0-1 1-2 2-2zm-5-29c0-9 7-16 16-16s17 7 17 16-8 16-17 16-16-7-16-16zm200 45c0-9 7-16 16-16s17 7 17 16-8 16-17 16-16-7-16-16zm2 0c0 8 6 14 14 14s15-6 15-14-7-15-15-15-14 7-14 15zm23 8h-4l-4-6h-4v6h-3v-17h7c4 0 7 2 7 5s-2 4-4 5zm-12-14v5h4c2 0 4-1 4-3s-2-2-4-2h-4z" fill="currentColor"></path></symbol><symbol id="icon-play" viewbox="0 0 85 100"><path d="M81 44.6c5 3 5 7.8 0 10.8L9 98.7c-5 3-9 .7-9-5V6.3c0-5.7 4-8 9-5l72 43.3z" fill="currentColor"></path></symbol><symbol id="icon-pause" viewbox="0 0 60 100"><path d="M0 8c0-5 3-8 8-8s9 3 9 8v84c0 5-4 8-9 8s-8-3-8-8V8zm43 0c0-5 3-8 8-8s8 3 8 8v84c0 5-3 8-8 8s-8-3-8-8V8z" fill="currentColor"></path></symbol><symbol id="icon-explicit" viewbox="0 0 20 20"><path d="M9 9V7h4V5H7v10h6v-2H9v-2h4V9H9zM0 2.994C0 1.34 1.343 0 2.994 0h14.012C18.66 0 20 1.343 20 2.994v14.012C20 18.66 18.657 20 17.006 20H2.994C1.34 20 0 18.657 0 17.006V2.994z" fill="currentColor"></path></symbol><symbol id="icon-close" viewbox="0 0 2016 2016"><path d="M1681 1512q35 35 35 84.5t-35 84.5-84.5 35-84.5-35l-504-504-504 504q-35 35-84.5 35t-84.5-35-35-84.5 35-84.5l504-504-504-504q-35-35-35-84.5t35-84.5q34-35 84-35 51 0 85 35l504 504 504-504q34-35 85-35 50 0 84 35 35 35 35 84.5t-35 84.5l-504 504 504 504z" fill="currentColor"></path></symbol></svg><div class="notice notice-info padding-notch" id="cookie-notice"><p>
#         We and <a href="https://www.spotify.com/us/legal/cookies-vendor-list/" rel="noopener" target="_blank">our partners</a> use cookies to personalize your experience, to show you ads based on your interests, and for measurement and analytics purposes. By using our website and our services, you agree to our use of cookies as described in our <a href="https://www.spotify.com/legal/cookies-policy/" rel="noopener" target="_blank">Cookie Policy</a>.
#     </p><button aria-label="Close" type="button">×</button></div><div class="notice notice-warning padding-notch" id="browser-support-notice"><p>
#     This browser doesn't support Spotify Web Player. <a href="https://support.spotify.com/using_spotify/the_basics/webplayer">Switch browsers</a> or <a href="https://www.spotify.com/download">download Spotify</a> for your desktop.
#   </p></div><header style="background-color: #d82241"><div class="overlay"></div><div class="wrapper padding-notch"><div id="main-header"><a class="logo-link" href="/browse"><svg><use xlink:href="#spotify-logo" xmlns:xlink="http://www.w3.org/1999/xlink"></use></svg></a></div><div class="entity "><div class="entity-info media"><div class="media-img"><button aria-label="Play" class="cover-art light shadow actionable playable-context js-cover-art js-playable " data-preview="" data-track-type="cover-art" data-uri="spotify:playlist:37i9dQZEVXbMnZEatlMSiu"><div class="cover-art-image" style="background-image:url(//charts-images.scdn.co/assets/locale_en/regional/daily/region_tw_large.jpg), linear-gradient(transparent,rgba(0,0,0,0.5)); background-color: #d82241"></div><div class="cover-art-playback" dir="ltr"><svg class="icon-play"><use xlink:href="#icon-play" xmlns:xlink="http://www.w3.org/1999/xlink"></use></svg><svg class="icon-pause"><use xlink:href="#icon-pause" xmlns:xlink="http://www.w3.org/1999/xlink"></use></svg></div></button></div><div class="media-bd"><h1><span dir="auto">Taiwan Top 50</span></h1><h2>By <a href="/user/spotifycharts">spotifycharts</a></h2><p class="entity-long-description"><span dir="auto">Your daily update of the most played tracks in Taiwan right now.</span></p><p class="text-silence entity-additional-info">50 songs</p><button class="btn btn-green entity-cta js-action-button" data-track-type="button-header"><span class="js-action-label">Play on Spotify</span></button></div></div><div class="tracklist-container"><ol class="tracklist js-track-list playable-context "><li class="tracklist-row js-track-row tracklist-row--track track-has-preview" data-position="1" role="button" tabindex="0"><div class="tracklist-col position-outer"><div class="play-pause top-align"><svg aria-label="Play" class="svg-play" role="button"><use xlink:href="#icon-play" xmlns:xlink="http://www.w3.org/1999/xlink"></use></svg><svg aria-label="Pause" class="svg-pause" role="button"><use xlink:href="#icon-pause" xmlns:xlink="http://www.w3.org/1999/xlink"></use></svg></div><div class="tracklist-col__track-number position top-align">
#                       1.
#                   </div></div><div class="tracklist-col name"><div class="top-align track-name-wrapper"><span class="track-name" dir="auto">刻在我心底的名字 (Your Name Engraved Herein) - 電影&lt;刻在你心底的名字&gt;主題曲</span><span class="artists-albums"><a href="/artist/2JBUyLiFvpFPWdZGqIGYLD" tabindex="-1"><span dir="auto">Crowd Lu</span></a>     • <a href="/album/5RG4bEVKGMdLaEIv1dofR2" tabindex="-1"><span dir="auto">刻在我心底的名字 (Your Name Engraved Herein)</span></a></span></div></div><div class="tracklist-col explicit"></div><div class="tracklist-col duration"><div class="top-align"><span class="total-duration">5:20</span><span class="preview-duration">0:30</span></div></div><div class="progress-bar-outer"><div class="progress-bar"></div></div></li><li class="tracklist-row js-track-row tracklist-row--track track-has-preview" data-position="2" role="button" tabindex="0"><div class="tracklist-col position-outer"><div class="play-pause top-align"><svg aria-label="Play" class="svg-play" role="button"><use xlink:href="#icon-play" xmlns:xlink="http://www.w3.org/1999/xlink"></use></svg><svg aria-label="Pause" class="svg-pause" role="button"><use xlink:href="#icon-pause" xmlns:xlink="http://www.w3.org/1999/xlink"></use></svg></div><div class="tracklist-col__track-number position top-align">
#                       2.
#                   </div></div><div class="tracklist-col name"><div class="top-align track-name-wrapper"><span class="track-name" dir="auto">Celebrity</span><span class="artists-albums"><a href="/artist/3HqSLMAZ3g3d5poNaI7GOU" tabindex="-1"><span dir="auto">IU</span></a>     • <a href="/album/3mtDgtcl4bxDN73kIM216g" tabindex="-1"><span dir="auto">Celebrity</span></a></span></div></div><div class="tracklist-col explicit"></div><div class="tracklist-col duration"><div class="top-align"><span class="total-duration">3:15</span><span class="preview-duration">0:30</span></div></div><div class="progress-bar-outer"><div class="progress-bar"></div></div></li><li class="tracklist-row js-track-row tracklist-row--track track-has-preview" data-position="3" role="button" tabindex="0"><div class="tracklist-col position-outer"><div class="play-pause top-align"><svg aria-label="Play" class="svg-play" role="button"><use xlink:href="#icon-play" xmlns:xlink="http://www.w3.org/1999/xlink"></use></svg><svg aria-label="Pause" class="svg-pause" role="button"><use xlink:href="#icon-pause" xmlns:xlink="http://www.w3.org/1999/xlink"></use></svg></div><div class="tracklist-col__track-number position top-align">
#                       3.
#                   </div></div><div class="tracklist-col name"><div class="top-align track-name-wrapper"><span class="track-name" dir="auto">飞鸟和蝉</span><span class="artists-albums"><a href="/artist/6f4srX54JFrLNK4aTJe2Sc" tabindex="-1"><span dir="auto">Ren Ran</span></a>     • <a href="/album/4wQT3Fwlf2hxFpb0lEoyhf" tabindex="-1"><span dir="auto">飞鸟和蝉</span></a></span></div></div><div class="tracklist-col explicit"></div><div class="tracklist-col duration"><div class="top-align"><span class="total-duration">4:56</span><span class="preview-duration">0:30</span></div></div><div class="progress-bar-outer"><div class="progress-bar"></div></div></li><li class="tracklist-row js-track-row tracklist-row--track track-has-preview" data-position="4" role="button" tabindex="0"><div class="tracklist-col position-outer"><div class="play-pause top-align"><svg aria-label="Play" class="svg-play" role="button"><use xlink:href="#icon-play" xmlns:xlink="http://www.w3.org/1999/xlink"></use></svg><svg aria-label="Pause" class="svg-pause" role="button"><use xlink:href="#icon-pause" xmlns:xlink="http://www.w3.org/1999/xlink"></use></svg></div><div class="tracklist-col__track-number position top-align">
#                       4.
#                   </div></div><div class="tracklist-col name"><div class="top-align track-name-wrapper"><span class="track-name" dir="auto">想見你想見你想見你(電視劇"想見你"片尾曲)</span><span class="artists-albums"><a href="/artist/3TtgOeQcNkf9WVDA4xPBJM" tabindex="-1"><span dir="auto">831</span></a>     • <a href="/album/44M14sRDzNZBtfaSH9Au3i" tabindex="-1"><span dir="auto">想見你想見你想見你(電視劇"想見你"片尾曲)</span></a></span></div></div><div class="tracklist-col explicit"></div><div class="tracklist-col duration"><div class="top-align"><span class="total-duration">3:59</span><span class="preview-duration">0:30</span></div></div><div class="progress-bar-outer"><div class="progress-bar"></div></div></li><li class="tracklist-row js-track-row tracklist-row--track track-has-preview" data-position="5" role="button" tabindex="0"><div class="tracklist-col position-outer"><div class="play-pause top-align"><svg aria-label="Play" class="svg-play" role="button"><use xlink:href="#icon-play" xmlns:xlink="http://www.w3.org/1999/xlink"></use></svg><svg aria-label="Pause" class="svg-pause" role="button"><use xlink:href="#icon-pause" xmlns:xlink="http://www.w3.org/1999/xlink"></use></svg></div><div class="tracklist-col__track-number position top-align">
#                       5.
#                   </div></div><div class="tracklist-col name"><div class="top-align track-name-wrapper"><span class="track-name" dir="auto">在這座城市遺失了你</span><span class="artists-albums"><a href="/artist/6xErgeZYatiaQ36SB5bvi8" tabindex="-1"><span dir="auto">告五人</span></a>     • <a href="/album/6Vss0GQqlLtD4k3lSXnYI5" tabindex="-1"><span dir="auto">運氣來得若有似無</span></a></span></div></div><div class="tracklist-col explicit"></div><div class="tracklist-col duration"><div class="top-align"><span class="total-duration">5:57</span><span class="preview-duration">0:30</span></div></div><div class="progress-bar-outer"><div class="progress-bar"></div></div></li><li class="tracklist-row js-track-row tracklist-row--track track-has-preview" data-position="6" role="button" tabindex="0"><div class="tracklist-col position-outer"><div class="play-pause top-align"><svg aria-label="Play" class="svg-play" role="button"><use xlink:href="#icon-play" xmlns:xlink="http://www.w3.org/1999/xlink"></use></svg><svg aria-label="Pause" class="svg-pause" role="button"><use xlink:href="#icon-pause" xmlns:xlink="http://www.w3.org/1999/xlink"></use></svg></div><div class="tracklist-col__track-number position top-align">
#                       6.
#                   </div></div><div class="tracklist-col name"><div class="top-align track-name-wrapper"><span class="track-name" dir="auto">怎麼了</span><span class="artists-albums"><a href="/artist/5fEQLwq1BWWQNR8GzhOIvi" tabindex="-1"><span dir="auto">Eric Chou</span></a>     • <a href="/album/2lrmHLTedOpdP6TaZDZ77F" tabindex="-1"><span dir="auto">終於了解自由 (Deluxe)</span></a></span></div></div><div class="tracklist-col explicit"></div><div class="tracklist-col duration"><div class="top-align"><span class="total-duration">5:21</span><span class="preview-duration">0:30</span></div></div><div class="progress-bar-outer"><div class="progress-bar"></div></div></li><li class="tracklist-row js-track-row tracklist-row--track track-has-preview" data-position="7" role="button" tabindex="0"><div class="tracklist-col position-outer"><div class="play-pause top-align"><svg aria-label="Play" class="svg-play" role="button"><use xlink:href="#icon-play" xmlns:xlink="http://www.w3.org/1999/xlink"></use></svg><svg aria-label="Pause" class="svg-pause" role="button"><use xlink:href="#icon-pause" xmlns:xlink="http://www.w3.org/1999/xlink"></use></svg></div><div class="tracklist-col__track-number position top-align">
#                       7.
#                   </div></div><div class="tracklist-col name"><div class="top-align track-name-wrapper"><span class="track-name" dir="auto">drivers license</span><span class="artists-albums"><a href="/artist/1McMsnEElThX1knmY4oliG" tabindex="-1"><span dir="auto">Olivia Rodrigo</span></a>     • <a href="/album/66FPnVL9G4CMKy3wvaGTcr" tabindex="-1"><span dir="auto">drivers license</span></a></span></div></div><div class="tracklist-col explicit"><div class="top-align"><svg class="icon-explicit" title="Explicit"><use xlink:href="#icon-explicit" xmlns:xlink="http://www.w3.org/1999/xlink"></use></svg></div></div><div class="tracklist-col duration"><div class="top-align"><span class="total-duration">4:02</span><span class="preview-duration">0:30</span></div></div><div class="progress-bar-outer"><div class="progress-bar"></div></div></li><li class="tracklist-row js-track-row tracklist-row--track track-has-preview" data-position="8" role="button" tabindex="0"><div class="tracklist-col position-outer"><div class="play-pause top-align"><svg aria-label="Play" class="svg-play" role="button"><use xlink:href="#icon-play" xmlns:xlink="http://www.w3.org/1999/xlink"></use></svg><svg aria-label="Pause" class="svg-pause" role="button"><use xlink:href="#icon-pause" xmlns:xlink="http://www.w3.org/1999/xlink"></use></svg></div><div class="tracklist-col__track-number position top-align">
#                       8.
#                   </div></div><div class="tracklist-col name"><div class="top-align track-name-wrapper"><span class="track-name" dir="auto">Dynamite</span><span class="artists-albums"><a href="/artist/3Nrfpe0tUJi4K4DXYWgMUX" tabindex="-1"><span dir="auto">BTS</span></a>     • <a href="/album/2qehskW9lYGWfYb0xPZkrS" tabindex="-1"><span dir="auto">BE</span></a></span></div></div><div class="tracklist-col explicit"></div><div class="tracklist-col duration"><div class="top-align"><span class="total-duration">3:19</span><span class="preview-duration">0:30</span></div></div><div class="progress-bar-outer"><div class="progress-bar"></div></div></li><li class="tracklist-row js-track-row tracklist-row--track track-has-preview" data-position="9" role="button" tabindex="0"><div class="tracklist-col position-outer"><div class="play-pause top-align"><svg aria-label="Play" class="svg-play" role="button"><use xlink:href="#icon-play" xmlns:xlink="http://www.w3.org/1999/xlink"></use></svg><svg aria-label="Pause" class="svg-pause" role="button"><use xlink:href="#icon-pause" xmlns:xlink="http://www.w3.org/1999/xlink"></use></svg></div><div class="tracklist-col__track-number position top-align">
#                       9.
#                   </div></div><div class="tracklist-col name"><div class="top-align track-name-wrapper"><span class="track-name" dir="auto">因為你 所以我</span><span class="artists-albums"><a href="/artist/16s0YTFcyjP4kgFwt7ktrY" tabindex="-1"><span dir="auto">Mayday</span></a>     • <a href="/album/0bLc2MyuEEP8eiMnd6v5Rt" tabindex="-1"><span dir="auto">因為你 所以我</span></a></span></div></div><div class="tracklist-col explicit"></div><div class="tracklist-col duration"><div class="top-align"><span class="total-duration">4:41</span><span class="preview-duration">0:30</span></div></div><div class="progress-bar-outer"><div class="progress-bar"></div></div></li><li class="tracklist-row js-track-row tracklist-row--track track-has-preview" data-position="10" role="button" tabindex="0"><div class="tracklist-col position-outer"><div class="play-pause top-align"><svg aria-label="Play" class="svg-play" role="button"><use xlink:href="#icon-play" xmlns:xlink="http://www.w3.org/1999/xlink"></use></svg><svg aria-label="Pause" class="svg-pause" role="button"><use xlink:href="#icon-pause" xmlns:xlink="http://www.w3.org/1999/xlink"></use></svg></div><div class="tracklist-col__track-number position top-align">
#                       10.
#                   </div></div><div class="tracklist-col name"><div class="top-align track-name-wrapper"><span class="track-name" dir="auto">炎</span><span class="artists-albums"><a href="/artist/0blbVefuxOGltDBa00dspv" tabindex="-1"><span dir="auto">LiSA</span></a>     • <a href="/album/1KmL1EZ0Pg9Vj3rPYMDqHY" tabindex="-1"><span dir="auto">炎</span></a></span></div></div><div class="tracklist-col explicit"></div><div class="tracklist-col duration"><div class="top-align"><span class="total-duration">4:35</span><span class="preview-duration">0:30</span></div></div><div class="progress-bar-outer"><div class="progress-bar"></div></div></li><li class="tracklist-row js-track-row tracklist-row--track " data-position="11" role="button" tabindex="0"><div class="tracklist-col position-outer"><div class="play-pause top-align"><svg aria-label="Play" class="svg-play" role="button"><use xlink:href="#icon-play" xmlns:xlink="http://www.w3.org/1999/xlink"></use></svg><svg aria-label="Pause" class="svg-pause" role="button"><use xlink:href="#icon-pause" xmlns:xlink="http://www.w3.org/1999/xlink"></use></svg></div><div class="tracklist-col__track-number position top-align">
#                       11.
#                   </div></div><div class="tracklist-col name"><div class="top-align track-name-wrapper"><span class="track-name" dir="auto">她沒在看我</span><span class="artists-albums"><a href="/artist/2qXGNIlmY3JrYkxOWyXZsd" tabindex="-1"><span dir="auto">E.SO</span></a>     • <a href="/album/5qiMTeDKaY3cfqZeBG0xUY" tabindex="-1"><span dir="auto">Outta Body靈魂出竅</span></a></span></div></div><div class="tracklist-col explicit"></div><div class="tracklist-col duration"><div class="top-align"><span class="total-duration">2:58</span><span class="preview-duration">0:30</span></div></div><div class="progress-bar-outer"><div class="progress-bar"></div></div></li><li class="tracklist-row js-track-row tracklist-row--track track-has-preview" data-position="12" role="button" tabindex="0"><div class="tracklist-col position-outer"><div class="play-pause top-align"><svg aria-label="Play" class="svg-play" role="button"><use xlink:href="#icon-play" xmlns:xlink="http://www.w3.org/1999/xlink"></use></svg><svg aria-label="Pause" class="svg-pause" role="button"><use xlink:href="#icon-pause" xmlns:xlink="http://www.w3.org/1999/xlink"></use></svg></div><div class="tracklist-col__track-number position top-align">
#                       12.
#                   </div></div><div class="tracklist-col name"><div class="top-align track-name-wrapper"><span class="track-name" dir="auto">平凡天使</span><span class="artists-albums"><a href="/artist/7aRC4L63dBn3CiLDuWaLSI" tabindex="-1"><span dir="auto">G.E.M.</span></a>     • <a href="/album/6dOrr1HwvFh5vg1PKP4z4K" tabindex="-1"><span dir="auto">平凡天使</span></a></span></div></div><div class="tracklist-col explicit"></div><div class="tracklist-col duration"><div class="top-align"><span class="total-duration">3:33</span><span class="preview-duration">0:30</span></div></div><div class="progress-bar-outer"><div class="progress-bar"></div></div></li><li class="tracklist-row js-track-row tracklist-row--track track-has-preview" data-position="13" role="button" tabindex="0"><div class="tracklist-col position-outer"><div class="play-pause top-align"><svg aria-label="Play" class="svg-play" role="button"><use xlink:href="#icon-play" xmlns:xlink="http://www.w3.org/1999/xlink"></use></svg><svg aria-label="Pause" class="svg-pause" role="button"><use xlink:href="#icon-pause" xmlns:xlink="http://www.w3.org/1999/xlink"></use></svg></div><div class="tracklist-col__track-number position top-align">
#                       13.
#                   </div></div><div class="tracklist-col name"><div class="top-align track-name-wrapper"><span class="track-name" dir="auto">I'm Not Cool</span><span class="artists-albums"><a href="/artist/3UwlejyX2b458azZ7eCnHb" tabindex="-1"><span dir="auto">HyunA</span></a>     • <a href="/album/3aqj5OK6GGIZ1Bejw7g0JW" tabindex="-1"><span dir="auto">I’m Not Cool</span></a></span></div></div><div class="tracklist-col explicit"></div><div class="tracklist-col duration"><div class="top-align"><span class="total-duration">2:54</span><span class="preview-duration">0:30</span></div></div><div class="progress-bar-outer"><div class="progress-bar"></div></div></li><li class="tracklist-row js-track-row tracklist-row--track track-has-preview" data-position="14" role="button" tabindex="0"><div class="tracklist-col position-outer"><div class="play-pause top-align"><svg aria-label="Play" class="svg-play" role="button"><use xlink:href="#icon-play" xmlns:xlink="http://www.w3.org/1999/xlink"></use></svg><svg aria-label="Pause" class="svg-pause" role="button"><use xlink:href="#icon-pause" xmlns:xlink="http://www.w3.org/1999/xlink"></use></svg></div><div class="tracklist-col__track-number position top-align">
#                       14.
#                   </div></div><div class="tracklist-col name"><div class="top-align track-name-wrapper"><span class="track-name" dir="auto">嚣张</span><span class="artists-albums"><a href="/artist/1SZdTuxme3mOk0D9pUFrET" tabindex="-1"><span dir="auto">En</span></a>     • <a href="/album/7HBIfL5J50gkUIjSWMRWqw" tabindex="-1"><span dir="auto">嚣张</span></a></span></div></div><div class="tracklist-col explicit"></div><div class="tracklist-col duration"><div class="top-align"><span class="total-duration">4:13</span><span class="preview-duration">0:30</span></div></div><div class="progress-bar-outer"><div class="progress-bar"></div></div></li><li class="tracklist-row js-track-row tracklist-row--track track-has-preview" data-position="15" role="button" tabindex="0"><div class="tracklist-col position-outer"><div class="play-pause top-align"><svg aria-label="Play" class="svg-play" role="button"><use xlink:href="#icon-play" xmlns:xlink="http://www.w3.org/1999/xlink"></use></svg><svg aria-label="Pause" class="svg-pause" role="button"><use xlink:href="#icon-pause" xmlns:xlink="http://www.w3.org/1999/xlink"></use></svg></div><div class="tracklist-col__track-number position top-align">
#                       15.
#                   </div></div><div class="tracklist-col name"><div class="top-align track-name-wrapper"><span class="track-name" dir="auto">CHANGE</span><span class="artists-albums"><a href="/artist/2qXGNIlmY3JrYkxOWyXZsd" tabindex="-1"><span dir="auto">E.SO</span></a>     • <a href="/album/2ymoED9nkKBQeg9uyUIVlF" tabindex="-1"><span dir="auto">Outta Body</span></a></span></div></div><div class="tracklist-col explicit"></div><div class="tracklist-col duration"><div class="top-align"><span class="total-duration">2:41</span><span class="preview-duration">0:30</span></div></div><div class="progress-bar-outer"><div class="progress-bar"></div></div></li><li class="tracklist-row js-track-row tracklist-row--track track-has-preview" data-position="16" role="button" tabindex="0"><div class="tracklist-col position-outer"><div class="play-pause top-align"><svg aria-label="Play" class="svg-play" role="button"><use xlink:href="#icon-play" xmlns:xlink="http://www.w3.org/1999/xlink"></use></svg><svg aria-label="Pause" class="svg-pause" role="button"><use xlink:href="#icon-pause" xmlns:xlink="http://www.w3.org/1999/xlink"></use></svg></div><div class="tracklist-col__track-number position top-align">
#                       16.
#                   </div></div><div class="tracklist-col name"><div class="top-align track-name-wrapper"><span class="track-name" dir="auto">Anyone</span><span class="artists-albums"><a href="/artist/1uNFoZAHBGtllmzznpCI3s" tabindex="-1"><span dir="auto">Justin Bieber</span></a>     • <a href="/album/51kijm0sjZz0yOa3kVBPUU" tabindex="-1"><span dir="auto">Anyone</span></a></span></div></div><div class="tracklist-col explicit"></div><div class="tracklist-col duration"><div class="top-align"><span class="total-duration">3:10</span><span class="preview-duration">0:30</span></div></div><div class="progress-bar-outer"><div class="progress-bar"></div></div></li><li class="tracklist-row js-track-row tracklist-row--track track-has-preview" data-position="17" role="button" tabindex="0"><div class="tracklist-col position-outer"><div class="play-pause top-align"><svg aria-label="Play" class="svg-play" role="button"><use xlink:href="#icon-play" xmlns:xlink="http://www.w3.org/1999/xlink"></use></svg><svg aria-label="Pause" class="svg-pause" role="button"><use xlink:href="#icon-pause" xmlns:xlink="http://www.w3.org/1999/xlink"></use></svg></div><div class="tracklist-col__track-number position top-align">
#                       17.
#                   </div></div><div class="tracklist-col name"><div class="top-align track-name-wrapper"><span class="track-name" dir="auto">天黑請閉眼 (feat. 邱鋒澤)</span><span class="artists-albums"><a href="/artist/4MMQmzYiUiuD8VwjrJu3v6" tabindex="-1"><span dir="auto">Nine Chen</span></a>,                 <a href="/artist/6QYehwA9q6UQEMs1Vak0uy" tabindex="-1"><span dir="auto">Feng Ze</span></a>     • <a href="/album/4Rx7JsvDZWfL07FV9qchPX" tabindex="-1"><span dir="auto">天黑請閉眼 (feat. 邱鋒澤)</span></a></span></div></div><div class="tracklist-col explicit"></div><div class="tracklist-col duration"><div class="top-align"><span class="total-duration">4:46</span><span class="preview-duration">0:30</span></div></div><div class="progress-bar-outer"><div class="progress-bar"></div></div></li><li class="tracklist-row js-track-row tracklist-row--track track-has-preview" data-position="18" role="button" tabindex="0"><div class="tracklist-col position-outer"><div class="play-pause top-align"><svg aria-label="Play" class="svg-play" role="button"><use xlink:href="#icon-play" xmlns:xlink="http://www.w3.org/1999/xlink"></use></svg><svg aria-label="Pause" class="svg-pause" role="button"><use xlink:href="#icon-pause" xmlns:xlink="http://www.w3.org/1999/xlink"></use></svg></div><div class="tracklist-col__track-number position top-align">
#                       18.
#                   </div></div><div class="tracklist-col name"><div class="top-align track-name-wrapper"><span class="track-name" dir="auto">緩緩</span><span class="artists-albums"><a href="/artist/6noxsCszBEEK04kCehugOp" tabindex="-1"><span dir="auto">A-Mei Chang</span></a>     • <a href="/album/0kFLRxlKsc9uTgjLlOY8Oo" tabindex="-1"><span dir="auto">緩緩</span></a></span></div></div><div class="tracklist-col explicit"></div><div class="tracklist-col duration"><div class="top-align"><span class="total-duration">3:47</span><span class="preview-duration">0:30</span></div></div><div class="progress-bar-outer"><div class="progress-bar"></div></div></li><li class="tracklist-row js-track-row tracklist-row--track track-has-preview" data-position="19" role="button" tabindex="0"><div class="tracklist-col position-outer"><div class="play-pause top-align"><svg aria-label="Play" class="svg-play" role="button"><use xlink:href="#icon-play" xmlns:xlink="http://www.w3.org/1999/xlink"></use></svg><svg aria-label="Pause" class="svg-pause" role="button"><use xlink:href="#icon-pause" xmlns:xlink="http://www.w3.org/1999/xlink"></use></svg></div><div class="tracklist-col__track-number position top-align">
#                       19.
#                   </div></div><div class="tracklist-col name"><div class="top-align track-name-wrapper"><span class="track-name" dir="auto">正想著你呢</span><span class="artists-albums"><a href="/artist/6cMRDBCHMYjyCH2D0s6uzr" tabindex="-1"><span dir="auto">Chih Siou</span></a>     • <a href="/album/1hLOyMZ8n5dmBckqXkToIG" tabindex="-1"><span dir="auto">房間裡的大象</span></a></span></div></div><div class="tracklist-col explicit"></div><div class="tracklist-col duration"><div class="top-align"><span class="total-duration">3:25</span><span class="preview-duration">0:30</span></div></div><div class="progress-bar-outer"><div class="progress-bar"></div></div></li><li class="tracklist-row js-track-row tracklist-row--track track-has-preview" data-position="20" role="button" tabindex="0"><div class="tracklist-col position-outer"><div class="play-pause top-align"><svg aria-label="Play" class="svg-play" role="button"><use xlink:href="#icon-play" xmlns:xlink="http://www.w3.org/1999/xlink"></use></svg><svg aria-label="Pause" class="svg-pause" role="button"><use xlink:href="#icon-pause" xmlns:xlink="http://www.w3.org/1999/xlink"></use></svg></div><div class="tracklist-col__track-number position top-align">
#                       20.
#                   </div></div><div class="tracklist-col name"><div class="top-align track-name-wrapper"><span class="track-name" dir="auto">Without You</span><span class="artists-albums"><a href="/artist/4TcOznbEZBqev21LzAH4KE" tabindex="-1"><span dir="auto">高爾宣 OSN</span></a>     • <a href="/album/4b65l6XzLp2Eg6lDTMmO1k" tabindex="-1"><span dir="auto">#osnrap</span></a></span></div></div><div class="tracklist-col explicit"></div><div class="tracklist-col duration"><div class="top-align"><span class="total-duration">2:55</span><span class="preview-duration">0:30</span></div></div><div class="progress-bar-outer"><div class="progress-bar"></div></div></li><li class="tracklist-row js-track-row tracklist-row--track track-has-preview" data-position="21" role="button" tabindex="0"><div class="tracklist-col position-outer"><div class="play-pause top-align"><svg aria-label="Play" class="svg-play" role="button"><use xlink:href="#icon-play" xmlns:xlink="http://www.w3.org/1999/xlink"></use></svg><svg aria-label="Pause" class="svg-pause" role="button"><use xlink:href="#icon-pause" xmlns:xlink="http://www.w3.org/1999/xlink"></use></svg></div><div class="tracklist-col__track-number position top-align">
#                       21.
#                   </div></div><div class="tracklist-col name"><div class="top-align track-name-wrapper"><span class="track-name" dir="auto">Afterglow</span><span class="artists-albums"><a href="/artist/6eUKZXaKkcviH0Ku9w2n3V" tabindex="-1"><span dir="auto">Ed Sheeran</span></a>     • <a href="/album/5bb2Sf8jps2DTyI2urMThV" tabindex="-1"><span dir="auto">Afterglow</span></a></span></div></div><div class="tracklist-col explicit"></div><div class="tracklist-col duration"><div class="top-align"><span class="total-duration">3:05</span><span class="preview-duration">0:30</span></div></div><div class="progress-bar-outer"><div class="progress-bar"></div></div></li><li class="tracklist-row js-track-row tracklist-row--track track-has-preview" data-position="22" role="button" tabindex="0"><div class="tracklist-col position-outer"><div class="play-pause top-align"><svg aria-label="Play" class="svg-play" role="button"><use xlink:href="#icon-play" xmlns:xlink="http://www.w3.org/1999/xlink"></use></svg><svg aria-label="Pause" class="svg-pause" role="button"><use xlink:href="#icon-pause" xmlns:xlink="http://www.w3.org/1999/xlink"></use></svg></div><div class="tracklist-col__track-number position top-align">
#                       22.
#                   </div></div><div class="tracklist-col name"><div class="top-align track-name-wrapper"><span class="track-name" dir="auto">positions</span><span class="artists-albums"><a href="/artist/66CXWjxzNUsdJxJ2JdwvnR" tabindex="-1"><span dir="auto">Ariana Grande</span></a>     • <a href="/album/3euz4vS7ezKGnNSwgyvKcd" tabindex="-1"><span dir="auto">Positions</span></a></span></div></div><div class="tracklist-col explicit"><div class="top-align"><svg class="icon-explicit" title="Explicit"><use xlink:href="#icon-explicit" xmlns:xlink="http://www.w3.org/1999/xlink"></use></svg></div></div><div class="tracklist-col duration"><div class="top-align"><span class="total-duration">2:52</span><span class="preview-duration">0:30</span></div></div><div class="progress-bar-outer"><div class="progress-bar"></div></div></li><li class="tracklist-row js-track-row tracklist-row--track track-has-preview" data-position="23" role="button" tabindex="0"><div class="tracklist-col position-outer"><div class="play-pause top-align"><svg aria-label="Play" class="svg-play" role="button"><use xlink:href="#icon-play" xmlns:xlink="http://www.w3.org/1999/xlink"></use></svg><svg aria-label="Pause" class="svg-pause" role="button"><use xlink:href="#icon-pause" xmlns:xlink="http://www.w3.org/1999/xlink"></use></svg></div><div class="tracklist-col__track-number position top-align">
#                       23.
#                   </div></div><div class="tracklist-col name"><div class="top-align track-name-wrapper"><span class="track-name" dir="auto">說好不哭</span><span class="artists-albums"><a href="/artist/2elBjNSdBE2Y3f0j1mjrql" tabindex="-1"><span dir="auto">Jay Chou</span></a>,                 <a href="/artist/6H93wOohK6r1MwGh41Z4Nb" tabindex="-1"><span dir="auto">Ashin Chen</span></a>     • <a href="/album/1aNkIWX1Uz0mSUK3OAFygO" tabindex="-1"><span dir="auto">說好不哭</span></a></span></div></div><div class="tracklist-col explicit"></div><div class="tracklist-col duration"><div class="top-align"><span class="total-duration">3:42</span><span class="preview-duration">0:30</span></div></div><div class="progress-bar-outer"><div class="progress-bar"></div></div></li><li class="tracklist-row js-track-row tracklist-row--track track-has-preview" data-position="24" role="button" tabindex="0"><div class="tracklist-col position-outer"><div class="play-pause top-align"><svg aria-label="Play" class="svg-play" role="button"><use xlink:href="#icon-play" xmlns:xlink="http://www.w3.org/1999/xlink"></use></svg><svg aria-label="Pause" class="svg-pause" role="button"><use xlink:href="#icon-pause" xmlns:xlink="http://www.w3.org/1999/xlink"></use></svg></div><div class="tracklist-col__track-number position top-align">
#                       24.
#                   </div></div><div class="tracklist-col name"><div class="top-align track-name-wrapper"><span class="track-name" dir="auto">willow</span><span class="artists-albums"><a href="/artist/06HL4z0CvFAxyc27GXpf02" tabindex="-1"><span dir="auto">Taylor Swift</span></a>     • <a href="/album/5jmVg7rwRcgd6ARPAeYNSm" tabindex="-1"><span dir="auto">evermore</span></a></span></div></div><div class="tracklist-col explicit"></div><div class="tracklist-col duration"><div class="top-align"><span class="total-duration">3:34</span><span class="preview-duration">0:30</span></div></div><div class="progress-bar-outer"><div class="progress-bar"></div></div></li><li class="tracklist-row js-track-row tracklist-row--track track-has-preview" data-position="25" role="button" tabindex="0"><div class="tracklist-col position-outer"><div class="play-pause top-align"><svg aria-label="Play" class="svg-play" role="button"><use xlink:href="#icon-play" xmlns:xlink="http://www.w3.org/1999/xlink"></use></svg><svg aria-label="Pause" class="svg-pause" role="button"><use xlink:href="#icon-pause" xmlns:xlink="http://www.w3.org/1999/xlink"></use></svg></div><div class="tracklist-col__track-number position top-align">
#                       25.
#                   </div></div><div class="tracklist-col name"><div class="top-align track-name-wrapper"><span class="track-name" dir="auto">句號</span><span class="artists-albums"><a href="/artist/7aRC4L63dBn3CiLDuWaLSI" tabindex="-1"><span dir="auto">G.E.M.</span></a>     • <a href="/album/5BQmFN38iOhEhMVIdtvFhS" tabindex="-1"><span dir="auto">摩天動物園</span></a></span></div></div><div class="tracklist-col explicit"></div><div class="tracklist-col duration"><div class="top-align"><span class="total-duration">3:55</span><span class="preview-duration">0:30</span></div></div><div class="progress-bar-outer"><div class="progress-bar"></div></div></li><li class="tracklist-row js-track-row tracklist-row--track track-has-preview" data-position="26" role="button" tabindex="0"><div class="tracklist-col position-outer"><div class="play-pause top-align"><svg aria-label="Play" class="svg-play" role="button"><use xlink:href="#icon-play" xmlns:xlink="http://www.w3.org/1999/xlink"></use></svg><svg aria-label="Pause" class="svg-pause" role="button"><use xlink:href="#icon-pause" xmlns:xlink="http://www.w3.org/1999/xlink"></use></svg></div><div class="tracklist-col__track-number position top-align">
#                       26.
#                   </div></div><div class="tracklist-col name"><div class="top-align track-name-wrapper"><span class="track-name" dir="auto">Levitating (feat. DaBaby)</span><span class="artists-albums"><a href="/artist/6M2wZ9GZgrQXHCFfjv46we" tabindex="-1"><span dir="auto">Dua Lipa</span></a>,                 <a href="/artist/4r63FhuTkUYltbVAg5TQnk" tabindex="-1"><span dir="auto">DaBaby</span></a>     • <a href="/album/5lKlFlReHOLShQKyRv6AL9" tabindex="-1"><span dir="auto">Future Nostalgia</span></a></span></div></div><div class="tracklist-col explicit"></div><div class="tracklist-col duration"><div class="top-align"><span class="total-duration">3:23</span><span class="preview-duration">0:30</span></div></div><div class="progress-bar-outer"><div class="progress-bar"></div></div></li><li class="tracklist-row js-track-row tracklist-row--track track-has-preview" data-position="27" role="button" tabindex="0"><div class="tracklist-col position-outer"><div class="play-pause top-align"><svg aria-label="Play" class="svg-play" role="button"><use xlink:href="#icon-play" xmlns:xlink="http://www.w3.org/1999/xlink"></use></svg><svg aria-label="Pause" class="svg-pause" role="button"><use xlink:href="#icon-pause" xmlns:xlink="http://www.w3.org/1999/xlink"></use></svg></div><div class="tracklist-col__track-number position top-align">
#                       27.
#                   </div></div><div class="tracklist-col name"><div class="top-align track-name-wrapper"><span class="track-name" dir="auto">很久以後 - 電影《可不可以,你也剛好喜歡我》主題曲</span><span class="artists-albums"><a href="/artist/7aRC4L63dBn3CiLDuWaLSI" tabindex="-1"><span dir="auto">G.E.M.</span></a>     • <a href="/album/5BQmFN38iOhEhMVIdtvFhS" tabindex="-1"><span dir="auto">摩天動物園</span></a></span></div></div><div class="tracklist-col explicit"></div><div class="tracklist-col duration"><div class="top-align"><span class="total-duration">4:50</span><span class="preview-duration">0:30</span></div></div><div class="progress-bar-outer"><div class="progress-bar"></div></div></li><li class="tracklist-row js-track-row tracklist-row--track track-has-preview" data-position="28" role="button" tabindex="0"><div class="tracklist-col position-outer"><div class="play-pause top-align"><svg aria-label="Play" class="svg-play" role="button"><use xlink:href="#icon-play" xmlns:xlink="http://www.w3.org/1999/xlink"></use></svg><svg aria-label="Pause" class="svg-pause" role="button"><use xlink:href="#icon-pause" xmlns:xlink="http://www.w3.org/1999/xlink"></use></svg></div><div class="tracklist-col__track-number position top-align">
#                       28.
#                   </div></div><div class="tracklist-col name"><div class="top-align track-name-wrapper"><span class="track-name" dir="auto">少年</span><span class="artists-albums"><a href="/artist/6taSlFSqCqAEUHOliFyHt7" tabindex="-1"><span dir="auto">梦然</span></a>     • <a href="/album/5bXN7segGUJUfO1DvQ4QN2" tabindex="-1"><span dir="auto">少年</span></a></span></div></div><div class="tracklist-col explicit"></div><div class="tracklist-col duration"><div class="top-align"><span class="total-duration">3:56</span><span class="preview-duration">0:30</span></div></div><div class="progress-bar-outer"><div class="progress-bar"></div></div></li><li class="tracklist-row js-track-row tracklist-row--track track-has-preview" data-position="29" role="button" tabindex="0"><div class="tracklist-col position-outer"><div class="play-pause top-align"><svg aria-label="Play" class="svg-play" role="button"><use xlink:href="#icon-play" xmlns:xlink="http://www.w3.org/1999/xlink"></use></svg><svg aria-label="Pause" class="svg-pause" role="button"><use xlink:href="#icon-pause" xmlns:xlink="http://www.w3.org/1999/xlink"></use></svg></div><div class="tracklist-col__track-number position top-align">
#                       29.
#                   </div></div><div class="tracklist-col name"><div class="top-align track-name-wrapper"><span class="track-name" dir="auto">Monster (Shawn Mendes &amp; Justin Bieber)</span><span class="artists-albums"><a href="/artist/7n2wHs1TKAczGzO7Dd2rGr" tabindex="-1"><span dir="auto">Shawn Mendes</span></a>,                 <a href="/artist/1uNFoZAHBGtllmzznpCI3s" tabindex="-1"><span dir="auto">Justin Bieber</span></a>     • <a href="/album/3Lp4JKk2ZgNkybMRS3eZR5" tabindex="-1"><span dir="auto">Wonder</span></a></span></div></div><div class="tracklist-col explicit"></div><div class="tracklist-col duration"><div class="top-align"><span class="total-duration">2:58</span><span class="preview-duration">0:30</span></div></div><div class="progress-bar-outer"><div class="progress-bar"></div></div></li><li class="tracklist-row js-track-row tracklist-row--track track-has-preview" data-position="30" role="button" tabindex="0"><div class="tracklist-col position-outer"><div class="play-pause top-align"><svg aria-label="Play" class="svg-play" role="button"><use xlink:href="#icon-play" xmlns:xlink="http://www.w3.org/1999/xlink"></use></svg><svg aria-label="Pause" class="svg-pause" role="button"><use xlink:href="#icon-pause" xmlns:xlink="http://www.w3.org/1999/xlink"></use></svg></div><div class="tracklist-col__track-number position top-align">
#                       30.
#                   </div></div><div class="tracklist-col name"><div class="top-align track-name-wrapper"><span class="track-name" dir="auto">他們說我是沒有用的年輕人</span><span class="artists-albums"><a href="/artist/4xlAHgZnzzPHtoKnev0gwJ" tabindex="-1"><span dir="auto">Good Band</span></a>     • <a href="/album/52wbyXpG9wiklOacpLGrig" tabindex="-1"><span dir="auto">他們說我是沒有用的年輕人</span></a></span></div></div><div class="tracklist-col explicit"></div><div class="tracklist-col duration"><div class="top-align"><span class="total-duration">5:23</span><span class="preview-duration">0:30</span></div></div><div class="progress-bar-outer"><div class="progress-bar"></div></div></li></ol><button class="link js-action-button" data-track-type="view-all-button">View all on Spotify</button></div></div></div></header><section class="more-by"><div class="btn-scroll-wrapper"><a class="btn-scroll" href="#upsell" tabindex="-1"><svg viewbox="0 0 80 80"><path d="M40 42L73 6c4-4 10 1 6 6L43 49c-2 2-4 2-6 0L1 12C-3 8 4 2 8 6zm0 27l33-34c4-4 10 1 6 6L43 78c-2 2-4 2-6 0L1 41c-4-4 3-10 7-6z"></path></svg></a></div></section><section class="upsell " id="upsell" style="background-color: #d82241"><div class="overlay"></div><div class="wrapper padding-notch"><h1>Listen to Taiwan Top 50 now.</h1><p>Listen to Taiwan Top 50 in full in the Spotify app</p><button class="btn btn-green js-action-button" data-track-type="button-footer"><span class="js-action-label">Play on Spotify</span></button></div></section><footer><a class="logo-link" href="/browse"><svg><use xlink:href="#spotify-logo" xmlns:xlink="http://www.w3.org/1999/xlink"></use></svg></a><p class="legal"><a href="https://www.spotify.com/legal/" rel="noopener" target="_blank">Legal</a><br/><a href="https://www.spotify.com/legal/privacy-policy/" rel="noopener" target="_blank">Privacy</a><br/><a href="https://www.spotify.com/legal/cookies-policy/" rel="noopener" target="_blank">Cookies</a><br/><a href="https://www.spotify.com/legal/privacy-policy/#s3" rel="noopener" target="_blank">About Ads</a></p></footer></div>

# %%
song_name = data1.find_all("span",class_ = "track-name")

for i in song_name:
    try:
        print(i.text)
    except Exception:
        pass
print(len(song_name))
# Out:
# 刻在我心底的名字 (Your Name Engraved Herein) - 電影<刻在你心底的名字>主題曲
# Celebrity
# 飞鸟和蝉
# 想見你想見你想見你(電視劇"想見你"片尾曲)
# 在這座城市遺失了你
# 怎麼了
# drivers license
# Dynamite
# 因為你 所以我
# 炎
# 她沒在看我
# 平凡天使
# I'm Not Cool
# 嚣张
# CHANGE
# Anyone
# 天黑請閉眼 (feat. 邱鋒澤)
# 緩緩
# 正想著你呢
# Without You
# Afterglow
# positions
# 說好不哭
# willow
# 句號
# Levitating (feat. DaBaby)
# 很久以後 - 電影《可不可以,你也剛好喜歡我》主題曲
# 少年
# Monster (Shawn Mendes & Justin Bieber)
# 他們說我是沒有用的年輕人
# 30

# %%
time = data1.find_all("span",class_ = "total-duration")
for i in time:
    print(i.text)
print(len(time))
# Out:
# 5:20
# 3:15
# 4:56
# 3:59
# 5:57
# 5:21
# 4:02
# 3:19
# 4:41
# 4:35
# 2:58
# 3:33
# 2:54
# 4:13
# 2:41
# 3:10
# 4:46
# 3:47
# 3:25
# 2:55
# 3:05
# 2:52
# 3:42
# 3:34
# 3:55
# 3:23
# 4:50
# 3:56
# 2:58
# 5:23
# 30

# %%
data3 = data1.find_all("div",class_ = "tracklist-col name")
print(data3)
# Out:
# [<div class="tracklist-col name"><div class="top-align track-name-wrapper"><span class="track-name" dir="auto">刻在我心底的名字 (Your Name Engraved Herein) - 電影&lt;刻在你心底的名字&gt;主題曲</span><span class="artists-albums"><a href="/artist/2JBUyLiFvpFPWdZGqIGYLD" tabindex="-1"><span dir="auto">Crowd Lu</span></a>     • <a href="/album/5RG4bEVKGMdLaEIv1dofR2" tabindex="-1"><span dir="auto">刻在我心底的名字 (Your Name Engraved Herein)</span></a></span></div></div>, <div class="tracklist-col name"><div class="top-align track-name-wrapper"><span class="track-name" dir="auto">Celebrity</span><span class="artists-albums"><a href="/artist/3HqSLMAZ3g3d5poNaI7GOU" tabindex="-1"><span dir="auto">IU</span></a>     • <a href="/album/3mtDgtcl4bxDN73kIM216g" tabindex="-1"><span dir="auto">Celebrity</span></a></span></div></div>, <div class="tracklist-col name"><div class="top-align track-name-wrapper"><span class="track-name" dir="auto">飞鸟和蝉</span><span class="artists-albums"><a href="/artist/6f4srX54JFrLNK4aTJe2Sc" tabindex="-1"><span dir="auto">Ren Ran</span></a>     • <a href="/album/4wQT3Fwlf2hxFpb0lEoyhf" tabindex="-1"><span dir="auto">飞鸟和蝉</span></a></span></div></div>, <div class="tracklist-col name"><div class="top-align track-name-wrapper"><span class="track-name" dir="auto">想見你想見你想見你(電視劇"想見你"片尾曲)</span><span class="artists-albums"><a href="/artist/3TtgOeQcNkf9WVDA4xPBJM" tabindex="-1"><span dir="auto">831</span></a>     • <a href="/album/44M14sRDzNZBtfaSH9Au3i" tabindex="-1"><span dir="auto">想見你想見你想見你(電視劇"想見你"片尾曲)</span></a></span></div></div>, <div class="tracklist-col name"><div class="top-align track-name-wrapper"><span class="track-name" dir="auto">在這座城市遺失了你</span><span class="artists-albums"><a href="/artist/6xErgeZYatiaQ36SB5bvi8" tabindex="-1"><span dir="auto">告五人</span></a>     • <a href="/album/6Vss0GQqlLtD4k3lSXnYI5" tabindex="-1"><span dir="auto">運氣來得若有似無</span></a></span></div></div>, <div class="tracklist-col name"><div class="top-align track-name-wrapper"><span class="track-name" dir="auto">怎麼了</span><span class="artists-albums"><a href="/artist/5fEQLwq1BWWQNR8GzhOIvi" tabindex="-1"><span dir="auto">Eric Chou</span></a>     • <a href="/album/2lrmHLTedOpdP6TaZDZ77F" tabindex="-1"><span dir="auto">終於了解自由 (Deluxe)</span></a></span></div></div>, <div class="tracklist-col name"><div class="top-align track-name-wrapper"><span class="track-name" dir="auto">drivers license</span><span class="artists-albums"><a href="/artist/1McMsnEElThX1knmY4oliG" tabindex="-1"><span dir="auto">Olivia Rodrigo</span></a>     • <a href="/album/66FPnVL9G4CMKy3wvaGTcr" tabindex="-1"><span dir="auto">drivers license</span></a></span></div></div>, <div class="tracklist-col name"><div class="top-align track-name-wrapper"><span class="track-name" dir="auto">Dynamite</span><span class="artists-albums"><a href="/artist/3Nrfpe0tUJi4K4DXYWgMUX" tabindex="-1"><span dir="auto">BTS</span></a>     • <a href="/album/2qehskW9lYGWfYb0xPZkrS" tabindex="-1"><span dir="auto">BE</span></a></span></div></div>, <div class="tracklist-col name"><div class="top-align track-name-wrapper"><span class="track-name" dir="auto">因為你 所以我</span><span class="artists-albums"><a href="/artist/16s0YTFcyjP4kgFwt7ktrY" tabindex="-1"><span dir="auto">Mayday</span></a>     • <a href="/album/0bLc2MyuEEP8eiMnd6v5Rt" tabindex="-1"><span dir="auto">因為你 所以我</span></a></span></div></div>, <div class="tracklist-col name"><div class="top-align track-name-wrapper"><span class="track-name" dir="auto">炎</span><span class="artists-albums"><a href="/artist/0blbVefuxOGltDBa00dspv" tabindex="-1"><span dir="auto">LiSA</span></a>     • <a href="/album/1KmL1EZ0Pg9Vj3rPYMDqHY" tabindex="-1"><span dir="auto">炎</span></a></span></div></div>, <div class="tracklist-col name"><div class="top-align track-name-wrapper"><span class="track-name" dir="auto">她沒在看我</span><span class="artists-albums"><a href="/artist/2qXGNIlmY3JrYkxOWyXZsd" tabindex="-1"><span dir="auto">E.SO</span></a>     • <a href="/album/5qiMTeDKaY3cfqZeBG0xUY" tabindex ...

# %%
data4 = data1.find_all("span",class_ = "artists-albums")
print(data4[0])
# Out:
# <span class="artists-albums"><a href="/artist/2JBUyLiFvpFPWdZGqIGYLD" tabindex="-1"><span dir="auto">Crowd Lu</span></a>     • <a href="/album/5RG4bEVKGMdLaEIv1dofR2" tabindex="-1"><span dir="auto">刻在我心底的名字 (Your Name Engraved Herein)</span></a></span>

# %%
data5 = []
for i in data4:
    singer = i.find("span")
    data5.append(i.text)

# %%
split_list =[i.split("•") for i in data5]
print(split_list)
# Out:
# [['Crowd Lu     ', ' 刻在我心底的名字 (Your Name Engraved Herein)'], ['IU     ', ' Celebrity'], ['Ren Ran     ', ' 飞鸟和蝉'], ['831     ', ' 想見你想見你想見你(電視劇"想見你"片尾曲)'], ['告五人     ', ' 運氣來得若有似無'], ['Eric Chou     ', ' 終於了解自由 (Deluxe)'], ['Olivia Rodrigo     ', ' drivers license'], ['BTS     ', ' BE'], ['Mayday     ', ' 因為你 所以我'], ['LiSA     ', ' 炎'], ['E.SO     ', ' Outta Body靈魂出竅'], ['G.E.M.     ', ' 平凡天使'], ['HyunA     ', ' I’m Not Cool'], ['En     ', ' 嚣张'], ['E.SO     ', ' Outta Body'], ['Justin Bieber     ', ' Anyone'], ['Nine Chen,                 Feng Ze     ', ' 天黑請閉眼 (feat. 邱鋒澤)'], ['A-Mei Chang     ', ' 緩緩'], ['Chih Siou     ', ' 房間裡的大象'], ['高爾宣 OSN     ', ' #osnrap'], ['Ed Sheeran     ', ' Afterglow'], ['Ariana Grande     ', ' Positions'], ['Jay Chou,                 Ashin Chen     ', ' 說好不哭'], ['Taylor Swift     ', ' evermore'], ['G.E.M.     ', ' 摩天動物園'], ['Dua Lipa,                 DaBaby     ', ' Future Nostalgia'], ['G.E.M.     ', ' 摩天動物園'], ['梦然     ', ' 少年'], ['Shawn Mendes,                 Justin Bieber     ', ' Wonder'], ['Good Band     ', ' 他們說我是沒有用的年輕人']]

# %%
singers = []
songs = []
print(singers)
for i in split_list:
    #print(i)
    #print(i[1])
    singers.append(i[0])
    print(i[0])
    songs.append(i[1])
    print(i[1])
#print(songs)
# Out:
# []
# Crowd Lu
#  刻在我心底的名字 (Your Name Engraved Herein)
# IU
#  Celebrity
# Ren Ran
#  飞鸟和蝉
# 831
#  想見你想見你想見你(電視劇"想見你"片尾曲)
# 告五人
#  運氣來得若有似無
# Eric Chou
#  終於了解自由 (Deluxe)
# Olivia Rodrigo
#  drivers license
# BTS
#  BE
# Mayday
#  因為你 所以我
# LiSA
#  炎
# E.SO
#  Outta Body靈魂出竅
# G.E.M.
#  平凡天使
# HyunA
#  I’m Not Cool
# En
#  嚣张
# E.SO
#  Outta Body
# Justin Bieber
#  Anyone
# Nine Chen,                 Feng Ze
#  天黑請閉眼 (feat. 邱鋒澤)
# A-Mei Chang
#  緩緩
# Chih Siou
#  房間裡的大象
# 高爾宣 OSN
#  #osnrap
# Ed Sheeran
#  Afterglow
# Ariana Grande
#  Positions
# Jay Chou,                 Ashin Chen
#  說好不哭
# Taylor Swift
#  evermore
# G.E.M.
#  摩天動物園
# Dua Lipa,                 DaBaby
#  Future Nostalgia
# G.E.M.
#  摩天動物園
# 梦然
#  少年
# Shawn Mendes,                 Justin Bieber
#  Wonder
# Good Band
#  他們說我是沒有用的年輕人

# %%
print(singers)
# Out:
# ['Crowd Lu     ', 'IU     ', 'Ren Ran     ', '831     ', '告五人     ', 'Eric Chou     ', 'Olivia Rodrigo     ', 'BTS     ', 'Mayday     ', 'LiSA     ', 'E.SO     ', 'G.E.M.     ', 'HyunA     ', 'En     ', 'E.SO     ', 'Justin Bieber     ', 'Nine Chen,                 Feng Ze     ', 'A-Mei Chang     ', 'Chih Siou     ', '高爾宣 OSN     ', 'Ed Sheeran     ', 'Ariana Grande     ', 'Jay Chou,                 Ashin Chen     ', 'Taylor Swift     ', 'G.E.M.     ', 'Dua Lipa,                 DaBaby     ', 'G.E.M.     ', '梦然     ', 'Shawn Mendes,                 Justin Bieber     ', 'Good Band     ']

# %%
print(songs)
# Out:
# [' 刻在我心底的名字 (Your Name Engraved Herein)', ' Celebrity', ' 飞鸟和蝉', ' 想見你想見你想見你(電視劇"想見你"片尾曲)', ' 運氣來得若有似無', ' 終於了解自由 (Deluxe)', ' drivers license', ' BE', ' 因為你 所以我', ' 炎', ' Outta Body靈魂出竅', ' 平凡天使', ' I’m Not Cool', ' 嚣张', ' Outta Body', ' Anyone', ' 天黑請閉眼 (feat. 邱鋒澤)', ' 緩緩', ' 房間裡的大象', ' #osnrap', ' Afterglow', ' Positions', ' 說好不哭', ' evermore', ' 摩天動物園', ' Future Nostalgia', ' 摩天動物園', ' 少年', ' Wonder', ' 他們說我是沒有用的年輕人']

# %%
from datetime import date

today = date.today()
file_name = str(today) + '.csv'
file = open(file_name,'a+',encoding='utf8')
file.write("song,singer\n")

for i in range(len(singers)):
    data = f'{songs[i]},{singers[i]},\n'
    file.write(data)
